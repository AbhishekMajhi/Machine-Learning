# %% [markdown]
# ## Description

# %% [markdown]
# #### The dataset consists of features that describe characteristics of the cell nuclei present in a digitised image, these features are defined as follows:
#
# * **Radius:** the average distance from the center of the nucleus to each of the boundary points
# * **Texture:** the standard deviation of the gray-scale values, the gray-scale value represents the intensity of the shades of gray in each pixel of the image
# * **Perimeter:** the total distance of the boundary of the cell nucleus
# * **Area:** the number of pixels on the interior of the boundary and adding one-half of the pixels on the perimeter, to correct for the error caused by digitisation
# * **Smoothness:** the difference between the length of a radius length and the mean length of the two radius lines surrounding it, hence the local variation in radius lengths
# * **Compactness:** the perimeter and area are combined to obtain a measure of compactness of the cell nuclei
# * **Concavity:** the severity of concave portions of the contour, a high concavity means that the boundary of the cell nucleus has indentations, and thus is rather rough than smooth
# * **Concave points:** the number of concave portions of the contour of the cell nucleus
# * **Symmetry:** the symmetry is determined by first finding the longest line from boundary point to boundary point through the center of the nucleus, subsequently the relative length differences between the lines perpendicular to the longest line to the boundary in both directions are measured, attention should be given to nuclei where the longest line cuts through the boundary because of concavity
# * **Fractal dimension:** the fractal dimension is approximated by the "coastline approximation", the perimeter of the nucleus can be measured using different lengths of measuring sticks, as this length increases, the total length of the measured "coastline" decreases due to lower precision of the measurement, the theoretical fractal dimension is then determined by dividing the logarithm of the observed perimeter L(s) by the logarithm of the measuring stick length s, plotting log(L(s)) against log(s) and determining the negative value of the slope results in an approximation of the fractal dimension D, finally, the desired feature is determined by the calculation D - 1.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#from sklearn.datasets import load_breast_cancer

# %% [markdown]
# ## Data Preparation

# %%
cancer_data = pd.read_csv('data1.csv')

# %%
cancer_data.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
sample = cancer_data.head(20)

# %%
# import dataframe_image as dfi
# dfi.export(sample, 'dataframe.png',max_cols=33)

# %% [markdown]
# **So we will have 2 classs to predict.**

# %%
# Lets check for null value in our data set
cancer_data.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# Hopefully there is no null value in our data set.

# %%
# Lets see it visually.
sns.heatmap(cancer_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# As we can see no missing data.

# %% [markdown]
# #### Some preprocessing on our data frame..

# %%
cancer_data.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# So here our target column 'diagnosis' have to classes.

# %%
cancer_data.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# Here we have 212 malignant cases and 357 benign cases.

# %% [markdown]
# As our 'diagnosis' column contains text values, we need to convert them in 0(for benign) and 1(for malignant) format

# %%
cancer_data['diagnosis'].replace({'M': 1, 'B': 0}, inplace= True)

# %%
cancer_data.diagnosis.value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
cancer_data.head()
# Out:
#          id  diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302          1  ...          0.4601                  0.11890
# 1    842517          1  ...          0.2750                  0.08902
# 2  84300903          1  ...          0.3613                  0.08758
# 3  84348301          1  ...          0.6638                  0.17300
# 4  84358402          1  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# As we can see our diagnosis column has values 0 and 1 instead of 'B' and 'M'.

# %% [markdown]
# ## Some Data Analysis

# %%
# visualize data according to the malignant and benign cases.

sns.set_style('whitegrid')
sns.countplot(x = 'diagnosis', data= cancer_data,palette = 'RdBu_r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-78f741259b81> in <module>
#       2
#       3 #
# ----> 4 sns.countplot(x = 'diagnosis', data= cancer_data,palette = 'RdBu_r')
#
# NameError: name 'sns' is not defined

# %% [markdown]
# malignant- 1 and benign -0 <br>
# There is not much to do..

# %%
cancer_data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
sns.scatterplot(x = 'texture_mean', y = 'perimeter_mean', data = cancer_data)

# %% [markdown]
# ### Train test split

# %%
y = cancer_data.diagnosis  # label

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
x = cancer_data.drop(['diagnosis', 'id'], axis = 1)
# Here 'id', 'Unnamed: 32' are no use to us and 'diagnosis' is our target column so we droped them.

# %%
x.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        17.99         10.38  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.2, random_state = 101)

# %%
X_train
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 476        14.20         20.53  ...          0.2534                  0.07858
# 130        12.19         13.29  ...          0.3469                  0.09241
# 246        13.20         17.43  ...          0.2767                  0.07198
# 205        15.12         16.68  ...          0.3415                  0.09740
# 16         14.68         20.13  ...          0.3029                  0.08216
# ..           ...           ...  ...             ...                      ...
# 552        12.77         29.43  ...          0.2407                  0.06484
# 393        21.61         22.28  ...          0.3828                  0.10070
# 75         16.07         19.65  ...          0.2650                  0.06387
# 337        18.77         21.43  ...          0.3679                  0.09870
# 523        13.71         18.68  ...          0.2849                  0.09031
#
# [455 rows x 30 columns]

# %% [markdown]
# Here,<br>
# X_train shape is (455, 30)<br>
# Y_train shape is (455,)<br>
# X_test.shape is (114,30)<br>
# Y_test shape is (114,)

# %% [markdown]
# ### Scale our data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)  # we don't wanna fit our tests data..

# %%
X_train.shape
# Out:
# (455, 30)

# %% [markdown]
# ### Using SVM

# %%
from sklearn.svm import SVC

# %%
model_SVC= SVC()

# %%
model_SVC.fit(X_train,Y_train)
# Out:
# SVC()

# %%
model_pred = model_SVC.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(Y_test,model_pred))
print('\n')
print(classification_report(Y_test,model_pred))
# Out:
# [[71  1]
#  [ 1 41]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        72
#            1       0.98      0.98      0.98        42
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
from sklearn.metrics import plot_confusion_matrix,plot_precision_recall_curve

# %%
plot_confusion_matrix(model_SVC, X_test, Y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Accuracy=(TP+TN)/(TP+TN+FP+FN)
accuracy = (71 + 41)/(71 + 41 + 1 + 1)
print(accuracy)
# Out:
# 0.9824561403508771

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(Y_test, model_pred)

# %% [markdown]
# ##### plot the mse for SVM

# %%
plt.figure(figsize=(14,8))
plt.title('SVM with MSE {:10.4f}'.format(mse))
plt.plot(Y_test)
plt.plot(model_pred)

# %% [markdown]
# ## Using KNN

# %% [markdown]
# **Using PCA**

# %%
# from sklearn.decomposition import PCA
# pca = PCA(n_components=2)
# X_train = pca.fit_transform(X_train)
# X_test = pca.fit_transform(X_test)
# explained_variance=pca.explained_variance_ratio_

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.neighbors import KNeighborsClassifier


classifier = KNeighborsClassifier(n_neighbors=i)
trained_model=classifier.fit(X_train,Y_train)
trained_model.fit(X_train,Y_train )

# Predicting the Test set results

KNN_pred = classifier.predict(X_test)

# Making the Confusion Matrix



print(confusion_matrix(Y_test,KNN_pred))
print('\n')
print(classification_report(Y_test,KNN_pred))
# Out:
# [[72  0]
#  [ 5 37]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        72
#            1       1.00      0.88      0.94        42
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.94      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %% [markdown]
# ## Using LSTM

# %%
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam,RMSprop,Adadelta
from tensorflow.keras.layers import LSTM, Activation, Dense, Dropout, Input, BatchNormalization
import tensorflow as tf

# %%
num_epochs = 150
np.random.seed(101)

# %%
Y_train.shape
# Out:
# (455,)

# %%
# Model

data = Input((X_train.shape[1],1),dtype= 'float32')  # Input layer

X = LSTM(128,return_sequences =True)(data)
X = BatchNormalization()(X)
X = Dropout(0.5)(X)
X = LSTM(128,return_sequences = True)(X)
X = BatchNormalization()(X)
X = Dropout(0.5)(X)
X = LSTM(64,return_sequences = False)(X)
X = BatchNormalization()(X)
# X = Dropout(0.2)(X)
X = Dense(units=4)(X)
X = Dense(units=2)(X)
# use sigmoid
X = Activation('sigmoid')(X)   # sigmoid is for binary classification and softmax for multiclass classification.
model_lstm = Model(data, X)

# %%
model_lstm.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 30, 1)]           0
#
#  lstm (LSTM)                 (None, 30, 128)           66560
#
#  batch_normalization (BatchN  (None, 30, 128)          512
#  ormalization)
#
#  dropout (Dropout)           (None, 30, 128)           0
#
#  lstm_1 (LSTM)               (None, 30, 128)           131584
#
#  batch_normalization_1 (Batc  (None, 30, 128)          512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 30, 128)           0
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense (Dense)               (None, 4)                 260
#
#  dense_1 (Dense)             (None, 2)                 10
#
#  activation (Activation)     (None, 2)                 0
#
# =================================================================
# Total params: 249,102
# Trainable params: 248,462
# Non-trainable params: 640
# _________________________________________________________________

# %%
type(model_lstm)
# Out:
# keras.engine.functional.Functional

# %%
# don't load the model train and see for yourself.
#model_lstm.load_weights('/home/ultimatedude/Documents/Machine Learning/Code/Breast Cancer(DL)/Data and Model/Breast_cancer_LSTM_Model.h5')

# %%
# fun for converting our target to one_hot vectior format.

# def convert_to_one_hot(Y, C):  # Y - target column and C- is the number of classes(here its is 2).
#     Y = np.eye(C)[Y.reshape(-1)]
#     return Y

# %%
model_lstm.compile(optimizer= Adam(learning_rate= 0.001), loss= 'binary_crossentropy', metrics=['accuracy'])

# %%
Y_train = Y_train.to_numpy() # Y_train is series here so we converted into numpy array
Y_train_oh = tf.keras.utils.to_categorical(Y_train,2)  # one_hot vec format
type(Y_train)
# Out:
# numpy.ndarray

# %%
Y_test_oh = tf.keras.utils.to_categorical(Y_test.to_numpy(),2)  # converting Y_test to one_hot vec format

# %%
model_lstm.reset_states()
his_lstm = model_lstm.fit(X_train, Y_train_oh, epochs= num_epochs, batch_size = 40, shuffle=True, verbose = 2, validation_data= (X_test,Y_test_oh))
# Out:
# Epoch 1/150
# 12/12 - 0s - loss: 0.1811 - accuracy: 0.9407 - val_loss: 0.6295 - val_accuracy: 0.6316 - 414ms/epoch - 34ms/step
# Epoch 2/150
# 12/12 - 0s - loss: 0.1179 - accuracy: 0.9604 - val_loss: 0.6493 - val_accuracy: 0.6316 - 442ms/epoch - 37ms/step
# Epoch 3/150
# 12/12 - 0s - loss: 0.1816 - accuracy: 0.9407 - val_loss: 0.6873 - val_accuracy: 0.6316 - 406ms/epoch - 34ms/step
# Epoch 4/150
# 12/12 - 0s - loss: 0.1463 - accuracy: 0.9407 - val_loss: 0.7637 - val_accuracy: 0.6316 - 412ms/epoch - 34ms/step
# Epoch 5/150
# 12/12 - 0s - loss: 0.1045 - accuracy: 0.9648 - val_loss: 0.7753 - val_accuracy: 0.6316 - 407ms/epoch - 34ms/step
# Epoch 6/150
# 12/12 - 0s - loss: 0.1756 - accuracy: 0.9275 - val_loss: 0.8600 - val_accuracy: 0.6316 - 406ms/epoch - 34ms/step
# Epoch 7/150
# 12/12 - 0s - loss: 0.1628 - accuracy: 0.9495 - val_loss: 0.7380 - val_accuracy: 0.6316 - 413ms/epoch - 34ms/step
# Epoch 8/150
# 12/12 - 0s - loss: 0.1412 - accuracy: 0.9538 - val_loss: 0.7451 - val_accuracy: 0.6316 - 403ms/epoch - 34ms/step
# Epoch 9/150
# 12/12 - 0s - loss: 0.1613 - accuracy: 0.9297 - val_loss: 0.7652 - val_accuracy: 0.6316 - 407ms/epoch - 34ms/step
# Epoch 10/150
# 12/12 - 0s - loss: 0.1499 - accuracy: 0.9516 - val_loss: 0.8090 - val_accuracy: 0.6316 - 412ms/epoch - 34ms/step
# Epoch 11/150
# 12/12 - 0s - loss: 0.1191 - accuracy: 0.9516 - val_loss: 0.7729 - val_accuracy: 0.6316 - 409ms/epoch - 34ms/step
# Epoch 12/150
# 12/12 - 0s - loss: 0.1220 - accuracy: 0.9516 - val_loss: 0.6982 - val_accuracy: 0.6316 - 410ms/epoch - 34ms/step
# Epoch 13/150
# 12/12 - 0s - loss: 0.1297 - accuracy: 0.9516 - val_loss: 0.7377 - val_accuracy: 0.6404 - 407ms/epoch - 34ms/step
# Epoch 14/150
# 12/12 - 0s - loss: 0.1191 - accuracy: 0.9560 - val_loss: 0.7605 - val_accuracy: 0.6404 - 413ms/epoch - 34ms/step
# Epoch 15/150
# 12/12 - 0s - loss: 0.1132 - accuracy: 0.9538 - val_loss: 0.9415 - val_accuracy: 0.6316 - 415ms/epoch - 35ms/step
# Epoch 16/150
# 12/12 - 0s - loss: 0.1394 - accuracy: 0.9495 - val_loss: 0.7923 - val_accuracy: 0.6404 - 430ms/epoch - 36ms/step
# Epoch 17/150
# 12/12 - 0s - loss: 0.1011 - accuracy: 0.9560 - val_loss: 0.6908 - val_accuracy: 0.6842 - 407ms/epoch - 34ms/step
# Epoch 18/150
# 12/12 - 0s - loss: 0.1554 - accuracy: 0.9495 - val_loss: 0.6035 - val_accuracy: 0.6667 - 422ms/epoch - 35ms/step
# Epoch 19/150
# 12/12 - 0s - loss: 0.1145 - accuracy: 0.9560 - val_loss: 0.7667 - val_accuracy: 0.6754 - 436ms/epoch - 36ms/step
# Epoch 20/150
# 12/12 - 0s - loss: 0.0952 - accuracy: 0.9626 - val_loss: 1.1177 - val_accuracy: 0.6491 - 404ms/epoch - 34ms/step
# Epoch 21/150
# 12/12 - 0s - loss: 0.1282 - accuracy: 0.9604 - val_loss: 0.9945 - val_accuracy: 0.6754 - 422ms/epoch - 35ms/step
# Epoch 22/150
# 12/12 - 0s - loss: 0.1475 - accuracy: 0.9429 - val_loss: 0.8501 - val_accuracy: 0.6579 - 427ms/epoch - 36ms/step
# Epoch 23/150
# 12/12 - 0s - loss: 0.1200 - accuracy: 0.9538 - val_loss: 1.1489 - val_accuracy: 0.6491 - 435ms/epoch - 36ms/step
# Epoch 24/150
# 12/12 - 0s - loss: 0.1327 - accuracy: 0.9538 - val_loss: 0.6364 - val_accuracy: 0.7368 - 415ms/epoch - 35ms/step
# Epoch 25/150
# 12/12 - 0s - loss: 0.1589 - accuracy: 0.9451 - val_loss: 0.5845 - val_accuracy: 0.7281 - 407ms/epoch - 34ms/step
# Epoch 26/150
# 12/12 - 0s - loss: 0.0900 - accuracy: 0.9604 - val_loss: 0.9353 - val_accuracy: 0.7105 - 409ms/epoch - 34ms/step
# Epoch 27/150
# 12/12 - 0s - loss: 0.1095 - accuracy: 0.9648 - val_loss: 0.7587 - val_accuracy: 0.7193 - 417ms/epoch - 35ms/step
# Epoch 28/150
# 12/12 - 0s - loss: 0.1148 - accuracy: 0.9560 - val_loss: 0.8899 - val_accuracy: 0.6842 - 411ms/epoch - 34ms/step
# Epoch 29/150
# 12/12 - 0s - loss: 0.0997 - accuracy: 0.9648 - val_loss: 0.4692 - val_accuracy: 0.7807 - 411ms/epoch - 34ms/step
# Epoch 30/150
# 12/12 - 0s - loss: 0.1103 - accuracy: 0.9582 - val_loss: 0.9684 - val_accuracy: 0.6930 - 407ms/epoch - 34ms/step
# Epoch 31/150
# 12/12 - 0s - loss: 0.1186 - accuracy: 0.9538 - val_loss: 0.6434 - val_accuracy: 0.7368 - 414ms/epoch - 34ms/step
# Epoch 32/150
# 12/12 - 0s - loss: 0.1062 - accuracy: 0.9604 - val_loss: 0.5817 - val_accuracy: 0.7807 - 402ms/epoch - 34ms/step
# Epoch 33/150
# 12/12 - 0s - loss: 0.0864 - accuracy: 0.9758 - val_loss: 0.4604 - val_accuracy: 0.7895 - 440ms/epoch - 37ms/step
# Epoch 34/150
# 12/12 - 0s - loss: 0.1204 - accuracy: 0.9626 - val_loss: 0.2814 - val_accuracy: 0.8772 - 409ms/epoch - 34ms/step
# Epoch 35/150
# 12/12 - 0s - loss: 0.1360 - accuracy: 0.9429 - val_loss: 0.3011 - val_accuracy: 0.8772 - 404ms/epoch - 34ms/step
# Epoch 36/150
# 12/12 - 0s - loss: 0.1081 - accuracy: 0.9648 - val_loss: 0.2351 - val_accuracy: 0.9035 - 413ms/epoch - 34ms/step
# Epoch 37/150
# 12/12 - 0s - loss: 0.0800 - accuracy: 0.9692 - val_loss: 0.4298 - val_accuracy: 0.8421 - 406ms/epoch - 34ms/step
# Epoch 38/150
# 12/12 - 0s - loss: 0.1342 - accuracy: 0.9538 - val_loss: 0.3242 - val_accuracy: 0.8772 - 417ms/epoch - 35ms/step
# Epoch 39/150
# 12/12 - 0s - loss: 0.0986 - accuracy: 0.9626 - val_loss: 0.2654 - val_accuracy: 0.9035 - 403ms/epoch - 34ms/step
# Epoch 40/150
# 12/12 - 0s - loss: 0.1485 - accuracy: 0.9363 - val_loss: 0.4064 - val_accuracy: 0.7982 - 410ms/epoch - 34ms/step
# Epoch 41/150
# 12/12 - 0s - loss: 0.1247 - accuracy: 0.9495 - val_loss: 0.3252 - val_accuracy: 0.8684 - 408ms/epoch - 34ms/step
# Epoch 42/150
# 12/12 - 0s - loss: 0.0915 - accuracy: 0.9626 - val_loss: 0.2892 - val_accuracy: 0.9123 - 433ms/epoch - 36ms/step
# Epoch 43/150
# 12/12 - 0s - loss: 0.0959 - accuracy: 0.9692 - val_loss: 0.1703 - val_accuracy: 0.9386 - 416ms/epoch - 35ms/step
# Epoch 44/150
# 12/12 - 0s - loss: 0.0899 - accuracy: 0.9670 - val_loss: 0.2593 - val_accuracy: 0.9035 - 408ms/epoch - 34ms/step
# Epoch 45/150
# 12/12 - 0s - loss: 0.1173 - accuracy: 0.9582 - val_loss: 0.1300 - val_accuracy: 0.9561 - 432ms/epoch - 36ms/step
# Epoch 46/150
# 12/12 - 0s - loss: 0.1039 - accuracy: 0.9538 - val_loss: 0.1626 - val_accuracy: 0.9474 - 415ms/epoch - 35ms/step
# Epoch 47/150
# 12/12 - 0s - loss: 0.0975 - accuracy: 0.9560 - val_loss: 0.1472 - val_accuracy: 0.9386 - 405ms/epoch - 34ms/step
# Epoch 48/150
# 12/12 - 0s - loss: 0.1027 - accuracy: 0.9538 - val_loss: 0.1277 - val_accuracy: 0.9386 - 436ms/epoch - 36ms/step
# Epoch 49/150
# 12/12 - 0s - loss: 0.0908 - accuracy: 0.9670 - val_loss: 0.1591 - val_accuracy: 0.9123 - 415ms/epoch - 35ms/step
# Epoch 50/150
# 12/12 - 0s - loss: 0.0722 - accuracy: 0.9714 - val_loss: 0.1674 - val_accuracy: 0.9211 - 408ms/epoch - 34ms/step
# Epoch 51/150
# 12/12 - 0s - loss: 0.0809 - accuracy: 0.9758 - val_loss: 0.1888 - val_accuracy: 0.9298 - 409ms/epoch - 34ms/step
# Epoch 52/150
# 12/12 - 0s - loss: 0.0828 - accuracy: 0.9692 - val_loss: 0.1499 - val_accuracy: 0.9386 - 408ms/epoch - 34ms/step
# Epoch 53/150
# 12/12 - 0s - loss: 0.0977 - accuracy: 0.9604 - val_loss: 0.2064 - val_accuracy: 0.9211 - 406ms/epoch - 34ms/step
# Epoch 54/150
# 12/12 - 0s - loss: 0.0822 - accuracy: 0.9670 - val_loss: 0.1866 - val_accuracy: 0.9298 - 400ms/epoch - 33ms/step
# Epoch 55/150
# 12/12 - 0s - loss: 0.1182 - accuracy: 0.9538 - val_loss: 0.1720 - val_accuracy: 0.9211 - 407ms/epoch - 34ms/step
# Epoch 56/150
# 12/12 - 0s - loss: 0.0992 - accuracy: 0.9516 - val_loss: 0.2558 - val_accuracy: 0.9035 - 415ms/epoch - 35ms/step
# Epoch 57/150
# 12/12 - 0s - loss: 0.0967 - accuracy: 0.9560 - val_loss: 0.2439 - val_accuracy: 0.9035 - 412ms/epoch - 34ms/step
# Epoch 58/150
# 12/12 - 0s - loss: 0.0940 - accuracy: 0.9626 - val_loss: 0.1577 - val_accuracy: 0.9386 - 417ms/epoch - 35ms/step
# Epoch 59/150
# 12/12 - 0s - loss: 0.0826 - accuracy: 0.9648 - val_loss: 0.1540 - val_accuracy: 0.9298 - 409ms/epoch - 34ms/step
# Epoch 60/150
# 12/12 - 0s - loss: 0.1048 - accuracy: 0.9560 - val_loss: 0.1490 - val_accuracy: 0.9386 - 418ms/epoch - 35ms/step
# Epoch 61/150
# 12/12 - 0s - loss: 0.0942 - accuracy: 0.9626 - val_loss: 0.1501 - val_accuracy: 0.9474 - 406ms/epoch - 34ms/step
# Epoch 62/150
# 12/12 - 0s - loss: 0.0943 - accuracy: 0.9648 - val_loss: 0.1361 - val_accuracy: 0.9474 - 408ms/epoch - 34ms/step
# Epoch 63/150
# 12/12 - 0s - loss: 0.0827 - accuracy: 0.9736 - val_loss: 0.2396 - val_accuracy: 0.9123 - 405ms/epoch - 34ms/step
# Epoch 64/150
# 12/12 - 0s - loss: 0.0811 - accuracy: 0.9692 - val_loss: 0.1513 - val_accuracy: 0.9474 - 407ms/epoch - 34ms/step
# Epoch 65/150
# 12/12 - 0s - loss: 0.1025 - accuracy: 0.9582 - val_loss: 0.1958 - val_accuracy: 0.9298 - 437ms/epoch - 36ms/step
# Epoch 66/150
# 12/12 - 0s - loss: 0.0950 - accuracy: 0.9692 - val_loss: 0.1601 - val_accuracy: 0.9298 - 405ms/epoch - 34ms/step
# Epoch 67/150
# 12/12 - 0s - loss: 0.0976 - accuracy: 0.9648 - val_loss: 0.2488 - val_accuracy: 0.9123 - 407ms/epoch - 34ms/step
# Epoch 68/150
# 12/12 - 0s - loss: 0.1287 - accuracy: 0.9429 - val_loss: 0.2284 - val_accuracy: 0.9298 - 408ms/epoch - 34ms/step
# Epoch 69/150
# 12/12 - 0s - loss: 0.0944 - accuracy: 0.9538 - val_loss: 0.1532 - val_accuracy: 0.9386 - 406ms/epoch - 34ms/step
# Epoch 70/150
# 12/12 - 0s - loss: 0.0652 - accuracy: 0.9714 - val_loss: 0.1456 - val_accuracy: 0.9386 - 413ms/epoch - 34ms/step
# Epoch 71/150
# 12/12 - 0s - loss: 0.0669 - accuracy: 0.9736 - val_loss: 0.1396 - val_accuracy: 0.9561 - 408ms/epoch - 34ms/step
# Epoch 72/150
# 12/12 - 0s - loss: 0.1182 - accuracy: 0.9516 - val_loss: 0.2217 - val_accuracy: 0.9298 - 411ms/epoch - 34ms/step
# Epoch 73/150
# 12/12 - 0s - loss: 0.0667 - accuracy: 0.9780 - val_loss: 0.1918 - val_accuracy: 0.9211 - 417ms/epoch - 35ms/step
# Epoch 74/150
# 12/12 - 0s - loss: 0.0881 - accuracy: 0.9692 - val_loss: 0.1408 - val_accuracy: 0.9386 - 421ms/epoch - 35ms/step
# Epoch 75/150
# 12/12 - 0s - loss: 0.0937 - accuracy: 0.9670 - val_loss: 0.1835 - val_accuracy: 0.9298 - 407ms/epoch - 34ms/step
# Epoch 76/150
# 12/12 - 0s - loss: 0.1013 - accuracy: 0.9670 - val_loss: 0.1990 - val_accuracy: 0.9298 - 404ms/epoch - 34ms/step
# Epoch 77/150
# 12/12 - 0s - loss: 0.1023 - accuracy: 0.9582 - val_loss: 0.1773 - val_accuracy: 0.9386 - 407ms/epoch - 34ms/step
# Epoch 78/150
# 12/12 - 0s - loss: 0.0996 - accuracy: 0.9582 - val_loss: 0.1770 - val_accuracy: 0.9298 - 405ms/epoch - 34ms/step
# Epoch 79/150
# 12/12 - 0s - loss: 0.0826 - accuracy: 0.9736 - val_loss: 0.2006 - val_accuracy: 0.9386 - 417ms/epoch - 35ms/step
# Epoch 80/150
# 12/12 - 0s - loss: 0.0711 - accuracy: 0.9714 - val_loss: 0.1881 - val_accuracy: 0.9386 - 443ms/epoch - 37ms/step
# Epoch 81/150
# 12/12 - 0s - loss: 0.1058 - accuracy: 0.9648 - val_loss: 0.1471 - val_accuracy: 0.9474 - 413ms/epoch - 34ms/step
# Epoch 82/150
# 12/12 - 0s - loss: 0.0756 - accuracy: 0.9648 - val_loss: 0.1800 - val_accuracy: 0.9474 - 406ms/epoch - 34ms/step
# Epoch 83/150
# 12/12 - 0s - loss: 0.1136 - accuracy: 0.9560 - val_loss: 0.2042 - val_accuracy: 0.9123 - 407ms/epoch - 34ms/step
# Epoch 84/150
# 12/12 - 0s - loss: 0.0922 - accuracy: 0.9582 - val_loss: 0.1552 - val_accuracy: 0.9386 - 413ms/epoch - 34ms/step
# Epoch 85/150
# 12/12 - 0s - loss: 0.1094 - accuracy: 0.9495 - val_loss: 0.1406 - val_accuracy: 0.9211 - 414ms/epoch - 34ms/step
# Epoch 86/150
# 12/12 - 0s - loss: 0.0860 - accuracy: 0.9692 - val_loss: 0.1206 - val_accuracy: 0.9386 - 408ms/epoch - 34ms/step
# Epoch 87/150
# 12/12 - 0s - loss: 0.0835 - accuracy: 0.9626 - val_loss: 0.1152 - val_accuracy: 0.9474 - 406ms/epoch - 34ms/step
# Epoch 88/150
# 12/12 - 0s - loss: 0.0841 - accuracy: 0.9692 - val_loss: 0.1698 - val_accuracy: 0.9386 - 406ms/epoch - 34ms/step
# Epoch 89/150
# 12/12 - 0s - loss: 0.0778 - accuracy: 0.9670 - val_loss: 0.1769 - val_accuracy: 0.9386 - 426ms/epoch - 35ms/step
# Epoch 90/150
# 12/12 - 0s - loss: 0.0644 - accuracy: 0.9802 - val_loss: 0.1491 - val_accuracy: 0.9561 - 441ms/epoch - 37ms/step
# Epoch 91/150
# 12/12 - 0s - loss: 0.0537 - accuracy: 0.9802 - val_loss: 0.1778 - val_accuracy: 0.9649 - 407ms/epoch - 34ms/step
# Epoch 92/150
# 12/12 - 0s - loss: 0.0749 - accuracy: 0.9560 - val_loss: 0.1640 - val_accuracy: 0.9298 - 409ms/epoch - 34ms/step
# Epoch 93/150
# 12/12 - 0s - loss: 0.0895 - accuracy: 0.9626 - val_loss: 0.1714 - val_accuracy: 0.9474 - 414ms/epoch - 35ms/step
# Epoch 94/150
# 12/12 - 0s - loss: 0.0565 - accuracy: 0.9758 - val_loss: 0.2066 - val_accuracy: 0.9474 - 403ms/epoch - 34ms/step
# Epoch 95/150
# 12/12 - 0s - loss: 0.0934 - accuracy: 0.9714 - val_loss: 0.1687 - val_accuracy: 0.9386 - 410ms/epoch - 34ms/step
# Epoch 96/150
# 12/12 - 0s - loss: 0.0923 - accuracy: 0.9648 - val_loss: 0.2293 - val_accuracy: 0.9123 - 436ms/epoch - 36ms/step
# Epoch 97/150
# 12/12 - 0s - loss: 0.0827 - accuracy: 0.9736 - val_loss: 0.1650 - val_accuracy: 0.9474 - 405ms/epoch - 34ms/step
# Epoch 98/150
# 12/12 - 0s - loss: 0.0756 - accuracy: 0.9648 - val_loss: 0.2311 - val_accuracy: 0.9298 - 403ms/epoch - 34ms/step
# Epoch 99/150
# 12/12 - 0s - loss: 0.0868 - accuracy: 0.9670 - val_loss: 0.1930 - val_accuracy: 0.9386 - 443ms/epoch - 37ms/step
# Epoch 100/150
# 12/12 - 0s - loss: 0.0773 - accuracy: 0.9736 - val_loss: 0.1862 - val_accuracy: 0.9474 - 414ms/epoch - 35ms/step
# Epoch 101/150
# 12/12 - 0s - loss: 0.0637 - accuracy: 0.9714 - val_loss: 0.1797 - val_accuracy: 0.9474 - 439ms/epoch - 37ms/step
# Epoch 102/150
# 12/12 - 0s - loss: 0.0414 - accuracy: 0.9868 - val_loss: 0.2133 - val_accuracy: 0.9386 - 437ms/epoch - 36ms/step
# Epoch 103/150
# 12/12 - 0s - loss: 0.0652 - accuracy: 0.9692 - val_loss: 0.1931 - val_accuracy: 0.9386 - 414ms/epoch - 34ms/step
# Epoch 104/150
# 12/12 - 0s - loss: 0.0830 - accuracy: 0.9736 - val_loss: 0.1299 - val_accuracy: 0.9561 - 409ms/epoch - 34ms/step
# Epoch 105/150
# 12/12 - 0s - loss: 0.0426 - accuracy: 0.9890 - val_loss: 0.1971 - val_accuracy: 0.9386 - 413ms/epoch - 34ms/step
# Epoch 106/150
# 12/12 - 0s - loss: 0.0715 - accuracy: 0.9736 - val_loss: 0.2021 - val_accuracy: 0.9298 - 411ms/epoch - 34ms/step
# Epoch 107/150
# 12/12 - 0s - loss: 0.1062 - accuracy: 0.9582 - val_loss: 0.1967 - val_accuracy: 0.9386 - 436ms/epoch - 36ms/step
# Epoch 108/150
# 12/12 - 0s - loss: 0.0828 - accuracy: 0.9692 - val_loss: 0.2075 - val_accuracy: 0.9298 - 409ms/epoch - 34ms/step
# Epoch 109/150
# 12/12 - 0s - loss: 0.0917 - accuracy: 0.9626 - val_loss: 0.1745 - val_accuracy: 0.9386 - 411ms/epoch - 34ms/step
# Epoch 110/150
# 12/12 - 0s - loss: 0.0549 - accuracy: 0.9758 - val_loss: 0.1952 - val_accuracy: 0.9386 - 416ms/epoch - 35ms/step
# Epoch 111/150
# 12/12 - 0s - loss: 0.0626 - accuracy: 0.9780 - val_loss: 0.1687 - val_accuracy: 0.9386 - 408ms/epoch - 34ms/step
# Epoch 112/150
# 12/12 - 0s - loss: 0.0643 - accuracy: 0.9780 - val_loss: 0.1644 - val_accuracy: 0.9474 - 408ms/epoch - 34ms/step
# Epoch 113/150
# 12/12 - 0s - loss: 0.0640 - accuracy: 0.9714 - val_loss: 0.1441 - val_accuracy: 0.9386 - 403ms/epoch - 34ms/step
# Epoch 114/150
# 12/12 - 0s - loss: 0.1413 - accuracy: 0.9516 - val_loss: 0.2140 - val_accuracy: 0.9298 - 446ms/epoch - 37ms/step
# Epoch 115/150
# 12/12 - 0s - loss: 0.0915 - accuracy: 0.9648 - val_loss: 0.1185 - val_accuracy: 0.9474 - 407ms/epoch - 34ms/step
# Epoch 116/150
# 12/12 - 0s - loss: 0.0708 - accuracy: 0.9670 - val_loss: 0.1428 - val_accuracy: 0.9474 - 437ms/epoch - 36ms/step
# Epoch 117/150
# 12/12 - 0s - loss: 0.0611 - accuracy: 0.9758 - val_loss: 0.1796 - val_accuracy: 0.9298 - 411ms/epoch - 34ms/step
# Epoch 118/150
# 12/12 - 0s - loss: 0.0619 - accuracy: 0.9802 - val_loss: 0.2183 - val_accuracy: 0.9298 - 408ms/epoch - 34ms/step
# Epoch 119/150
# 12/12 - 0s - loss: 0.0625 - accuracy: 0.9648 - val_loss: 0.1616 - val_accuracy: 0.9298 - 409ms/epoch - 34ms/step
# Epoch 120/150
# 12/12 - 0s - loss: 0.0946 - accuracy: 0.9604 - val_loss: 0.1787 - val_accuracy: 0.9386 - 409ms/epoch - 34ms/step
# Epoch 121/150
# 12/12 - 0s - loss: 0.0581 - accuracy: 0.9758 - val_loss: 0.1945 - val_accuracy: 0.9474 - 419ms/epoch - 35ms/step
# Epoch 122/150
# 12/12 - 0s - loss: 0.0861 - accuracy: 0.9714 - val_loss: 0.1877 - val_accuracy: 0.9123 - 443ms/epoch - 37ms/step
# Epoch 123/150
# 12/12 - 0s - loss: 0.0752 - accuracy: 0.9692 - val_loss: 0.1804 - val_accuracy: 0.9561 - 401ms/epoch - 33ms/step
# Epoch 124/150
# 12/12 - 0s - loss: 0.0722 - accuracy: 0.9780 - val_loss: 0.2275 - val_accuracy: 0.9035 - 409ms/epoch - 34ms/step
# Epoch 125/150
# 12/12 - 0s - loss: 0.0849 - accuracy: 0.9736 - val_loss: 0.1858 - val_accuracy: 0.9298 - 442ms/epoch - 37ms/step
# Epoch 126/150
# 12/12 - 0s - loss: 0.0612 - accuracy: 0.9736 - val_loss: 0.1538 - val_accuracy: 0.9561 - 441ms/epoch - 37ms/step
# Epoch 127/150
# 12/12 - 0s - loss: 0.0609 - accuracy: 0.9758 - val_loss: 0.1545 - val_accuracy: 0.9474 - 405ms/epoch - 34ms/step
# Epoch 128/150
# 12/12 - 0s - loss: 0.0817 - accuracy: 0.9670 - val_loss: 0.1713 - val_accuracy: 0.9474 - 406ms/epoch - 34ms/step
# Epoch 129/150
# 12/12 - 0s - loss: 0.0624 - accuracy: 0.9736 - val_loss: 0.1632 - val_accuracy: 0.9298 - 413ms/epoch - 34ms/step
# Epoch 130/150
# 12/12 - 0s - loss: 0.0403 - accuracy: 0.9890 - val_loss: 0.1707 - val_accuracy: 0.9561 - 416ms/epoch - 35ms/step
# Epoch 131/150
# 12/12 - 0s - loss: 0.0512 - accuracy: 0.9780 - val_loss: 0.1702 - val_accuracy: 0.9649 - 411ms/epoch - 34ms/step
# Epoch 132/150
# 12/12 - 0s - loss: 0.0397 - accuracy: 0.9868 - val_loss: 0.1514 - val_accuracy: 0.9474 - 405ms/epoch - 34ms/step
# Epoch 133/150
# 12/12 - 0s - loss: 0.0664 - accuracy: 0.9714 - val_loss: 0.1355 - val_accuracy: 0.9561 - 406ms/epoch - 34ms/step
# Epoch 134/150
# 12/12 - 0s - loss: 0.1011 - accuracy: 0.9648 - val_loss: 0.1730 - val_accuracy: 0.9386 - 407ms/epoch - 34ms/step
# Epoch 135/150
# 12/12 - 0s - loss: 0.0955 - accuracy: 0.9560 - val_loss: 0.1999 - val_accuracy: 0.9298 - 427ms/epoch - 36ms/step
# Epoch 136/150
# 12/12 - 0s - loss: 0.0610 - accuracy: 0.9736 - val_loss: 0.1483 - val_accuracy: 0.9649 - 407ms/epoch - 34ms/step
# Epoch 137/150
# 12/12 - 0s - loss: 0.0727 - accuracy: 0.9714 - val_loss: 0.1988 - val_accuracy: 0.9298 - 404ms/epoch - 34ms/step
# Epoch 138/150
# 12/12 - 0s - loss: 0.0632 - accuracy: 0.9736 - val_loss: 0.1736 - val_accuracy: 0.9474 - 411ms/epoch - 34ms/step
# Epoch 139/150
# 12/12 - 0s - loss: 0.0692 - accuracy: 0.9824 - val_loss: 0.1512 - val_accuracy: 0.9386 - 403ms/epoch - 34ms/step
# Epoch 140/150
# 12/12 - 0s - loss: 0.0630 - accuracy: 0.9736 - val_loss: 0.1490 - val_accuracy: 0.9386 - 442ms/epoch - 37ms/step
# Epoch 141/150
# 12/12 - 0s - loss: 0.0704 - accuracy: 0.9736 - val_loss: 0.1416 - val_accuracy: 0.9298 - 407ms/epoch - 34ms/step
# Epoch 142/150
# 12/12 - 0s - loss: 0.1050 - accuracy: 0.9604 - val_loss: 0.2216 - val_accuracy: 0.9211 - 405ms/epoch - 34ms/step
# Epoch 143/150
# 12/12 - 0s - loss: 0.0515 - accuracy: 0.9802 - val_loss: 0.2101 - val_accuracy: 0.9035 - 410ms/epoch - 34ms/step
# Epoch 144/150
# 12/12 - 0s - loss: 0.0626 - accuracy: 0.9780 - val_loss: 0.1911 - val_accuracy: 0.9123 - 436ms/epoch - 36ms/step
# Epoch 145/150
# 12/12 - 0s - loss: 0.0696 - accuracy: 0.9714 - val_loss: 0.1763 - val_accuracy: 0.9386 - 413ms/epoch - 34ms/step
# Epoch 146/150
# 12/12 - 0s - loss: 0.0732 - accuracy: 0.9736 - val_loss: 0.2444 - val_accuracy: 0.9123 - 406ms/epoch - 34ms/step
# Epoch 147/150
# 12/12 - 0s - loss: 0.0567 - accuracy: 0.9802 - val_loss: 0.1952 - val_accuracy: 0.9211 - 409ms/epoch - 34ms/step
# Epoch 148/150
# 12/12 - 0s - loss: 0.0753 - accuracy: 0.9736 - val_loss: 0.1592 - val_accuracy: 0.9649 - 436ms/epoch - 36ms/step
# Epoch 149/150
# 12/12 - 0s - loss: 0.0871 - accuracy: 0.9758 - val_loss: 0.1926 - val_accuracy: 0.9298 - 417ms/epoch - 35ms/step
# Epoch 150/150
# 12/12 - 0s - loss: 0.0543 - accuracy: 0.9802 - val_loss: 0.1731 - val_accuracy: 0.9211 - 406ms/epoch - 34ms/step

# %%
# summarize history for accuracy
def plot_history(history):
    plt.figure(figsize = (12,6))
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.figure(figsize = (12,6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
plot_history(his_lstm)

# %% [markdown]
# ### Now lets test the model

# %%
loss, acc = model_lstm.evaluate(X_test, Y_test_oh)
print()
print("Test accuracy = ", acc)
# Out:
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8051 - accuracy: 0.4474
#
# Test accuracy =  0.44736841320991516

# %%
model_lstm.save('cancer_model_lstm.h5')

# %% [markdown]
# #### Maximum accuracy achived around 92 - 93 percent on some research papaers..
# **Here we achived 94% of validation accuracy and it can be improved by**
# * Training for longer period of time(here we only train our model for 300 epochs but in some places its trained for 1000 to 2000 num of epochs).
# * Change the units parameter in **Dropout** layer(while using complex architecture and more number of neurons in LSTM layers its better to set max values(like 0.7, 0.8) as dropout parameter).
# * Often changing learning rate can improve model performance.
# * Use better data normalization technique. Here I use MinMaxScalar, we can also use StandardScaler.

# %% [markdown]
# #### Testing and Plotting stuffs

# %%
## Dataframe to strore acc,recall,precision and specificity.
cols = ['Accuracy', 'Precision', 'Recall', 'Specificity']
#index = ['SVM', 'KNN', 'LSTM', 'GRU', 'SimpleRNN']
summary_table = pd.DataFrame(columns= cols)
summary_table
# Out:
# Empty DataFrame
# Columns: [Accuracy, Precision, Recall, Specificity]
# Index: []

# %%
def get_confusion_matrix(Y_test_oh,model_pred):
    cm = confusion_matrix(Y_test_oh.argmax(axis = 1), model_pred.argmax(axis=1))

    True_Positives = cm[0][0]
    False_Positives = cm[0][1]

    True_Negetives = cm[1][1]
    False_Negetives = cm[1][0]

    return True_Positives,False_Positives,False_Negetives,True_Negetives

# %%
def get_cm_components(True_Positives,False_Positives,False_Negetives,True_Negetives):

    precision =  True_Positives / (True_Positives + False_Positives)
    recall = True_Positives / (True_Positives + False_Negetives)
    specificity = True_Negetives / (True_Negetives + False_Positives)

    return precision,recall,specificity

# %% [markdown]
# #### For LSTM

# %%
from sklearn.metrics import plot_confusion_matrix,plot_precision_recall_curve, confusion_matrix

# %%
# predictions
lstm_pred = model_lstm.predict(X_test)

# %%
True_Positives,False_Positives,False_Negetives,True_Negetives = get_confusion_matrix(Y_test_oh,lstm_pred)

# %%
print(True_Positives,end=' ')
print(False_Positives)
print(False_Negetives, end=' ')
print(True_Negetives)
# Out:
# 34 38
# 25 17

# %%
pre,rec,spe = get_cm_components(True_Positives,False_Positives,False_Negetives,True_Negetives)

# %%
vals = {'Accuracy':acc,'Precision':pre,'Recall':rec,'Specificity':spe}

# %%
data = pd.DataFrame(vals, index= ["LSTM"])
data
# Out:
#       Accuracy  Precision    Recall  Specificity
# LSTM  0.447368   0.472222  0.576271     0.309091

# %%
summary_table = pd.concat([summary_table, data])
summary_table
# Out:
#       Accuracy  Precision    Recall  Specificity
# LSTM  0.447368   0.472222  0.576271     0.309091

# %% [markdown]
# ### Using GRU

# %%
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam,RMSprop,Adadelta
from tensorflow.keras.layers import Activation, Dense, Dropout, Input, GRU, BatchNormalization
import tensorflow as tf

# %%
# Model

data = Input((X_train.shape[1],1),dtype= 'float32')  # Input layer

X = GRU(128,return_sequences =True)(data)
X = BatchNormalization()(X)
X = Dropout(0.5)(X)
X = GRU(128,return_sequences = True)(X)
X = BatchNormalization()(X)
X = Dropout(0.5)(X)
X = GRU(64,return_sequences = False)(X)
X = BatchNormalization()(X)
#X = Dropout(0.5)(X)
X = Dense(units=4)(X)
X = Dense(units=2)(X)
# use sigmoid
X = Activation('sigmoid')(X)   # sigmoid is for binary classification and softmax for multiclass classification.
model_GRU = Model(data, X)

# %%
model_GRU.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 30, 1)]           0
#
#  gru (GRU)                   (None, 30, 128)           50304
#
#  batch_normalization_3 (Batc  (None, 30, 128)          512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 30, 128)           0
#
#  gru_1 (GRU)                 (None, 30, 128)           99072
#
#  batch_normalization_4 (Batc  (None, 30, 128)          512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 30, 128)           0
#
#  gru_2 (GRU)                 (None, 64)                37248
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 4)                 260
#
#  dense_3 (Dense)             (None, 2)                 10
#
#  activation_1 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 188,174
# Trainable params: 187,534
# Non-trainable params: 640
# _________________________________________________________________

# %%
model_GRU.compile(optimizer= Adam(learning_rate= 0.001), loss= 'binary_crossentropy', metrics=['accuracy'])

# %%
hist_gru = model_GRU.fit(X_train, Y_train_oh, epochs= 150, batch_size = 40, shuffle=True, verbose = 2, validation_data = (X_test,Y_test_oh))
# Out:
# Epoch 1/150
# 12/12 - 8s - loss: 0.7044 - accuracy: 0.7143 - val_loss: 0.7104 - val_accuracy: 0.3684 - 8s/epoch - 650ms/step
# Epoch 2/150
# 12/12 - 0s - loss: 0.3278 - accuracy: 0.8857 - val_loss: 0.5927 - val_accuracy: 0.7544 - 387ms/epoch - 32ms/step
# Epoch 3/150
# 12/12 - 0s - loss: 0.2412 - accuracy: 0.9253 - val_loss: 0.4464 - val_accuracy: 0.8947 - 398ms/epoch - 33ms/step
# Epoch 4/150
# 12/12 - 0s - loss: 0.2451 - accuracy: 0.9143 - val_loss: 0.6617 - val_accuracy: 0.4474 - 389ms/epoch - 32ms/step
# Epoch 5/150
# 12/12 - 0s - loss: 0.2403 - accuracy: 0.9077 - val_loss: 0.7997 - val_accuracy: 0.3860 - 388ms/epoch - 32ms/step
# Epoch 6/150
# 12/12 - 0s - loss: 0.1894 - accuracy: 0.9341 - val_loss: 0.8613 - val_accuracy: 0.3947 - 392ms/epoch - 33ms/step
# Epoch 7/150
# 12/12 - 0s - loss: 0.1831 - accuracy: 0.9253 - val_loss: 0.5432 - val_accuracy: 0.6667 - 391ms/epoch - 33ms/step
# Epoch 8/150
# 12/12 - 0s - loss: 0.1933 - accuracy: 0.9253 - val_loss: 0.4850 - val_accuracy: 0.7544 - 390ms/epoch - 33ms/step
# Epoch 9/150
# 12/12 - 0s - loss: 0.1621 - accuracy: 0.9341 - val_loss: 1.1772 - val_accuracy: 0.3772 - 387ms/epoch - 32ms/step
# Epoch 10/150
# 12/12 - 0s - loss: 0.1429 - accuracy: 0.9516 - val_loss: 0.3675 - val_accuracy: 0.8246 - 394ms/epoch - 33ms/step
# Epoch 11/150
# 12/12 - 0s - loss: 0.1590 - accuracy: 0.9385 - val_loss: 0.9909 - val_accuracy: 0.4211 - 388ms/epoch - 32ms/step
# Epoch 12/150
# 12/12 - 0s - loss: 0.2183 - accuracy: 0.9121 - val_loss: 0.5152 - val_accuracy: 0.7105 - 401ms/epoch - 33ms/step
# Epoch 13/150
# 12/12 - 0s - loss: 0.1324 - accuracy: 0.9429 - val_loss: 0.6610 - val_accuracy: 0.6404 - 396ms/epoch - 33ms/step
# Epoch 14/150
# 12/12 - 0s - loss: 0.1597 - accuracy: 0.9385 - val_loss: 0.3089 - val_accuracy: 0.8421 - 388ms/epoch - 32ms/step
# Epoch 15/150
# 12/12 - 0s - loss: 0.1582 - accuracy: 0.9407 - val_loss: 0.8940 - val_accuracy: 0.5439 - 387ms/epoch - 32ms/step
# Epoch 16/150
# 12/12 - 0s - loss: 0.1746 - accuracy: 0.9385 - val_loss: 0.8364 - val_accuracy: 0.5088 - 387ms/epoch - 32ms/step
# Epoch 17/150
# 12/12 - 0s - loss: 0.1427 - accuracy: 0.9451 - val_loss: 0.7242 - val_accuracy: 0.5965 - 387ms/epoch - 32ms/step
# Epoch 18/150
# 12/12 - 0s - loss: 0.1786 - accuracy: 0.9429 - val_loss: 1.9346 - val_accuracy: 0.3772 - 392ms/epoch - 33ms/step
# Epoch 19/150
# 12/12 - 0s - loss: 0.1392 - accuracy: 0.9473 - val_loss: 0.5032 - val_accuracy: 0.7281 - 421ms/epoch - 35ms/step
# Epoch 20/150
# 12/12 - 0s - loss: 0.1116 - accuracy: 0.9560 - val_loss: 0.9018 - val_accuracy: 0.5877 - 387ms/epoch - 32ms/step
# Epoch 21/150
# 12/12 - 0s - loss: 0.1539 - accuracy: 0.9385 - val_loss: 0.1098 - val_accuracy: 0.9825 - 389ms/epoch - 32ms/step
# Epoch 22/150
# 12/12 - 0s - loss: 0.1223 - accuracy: 0.9560 - val_loss: 0.9088 - val_accuracy: 0.6140 - 392ms/epoch - 33ms/step
# Epoch 23/150
# 12/12 - 0s - loss: 0.1743 - accuracy: 0.9275 - val_loss: 0.1961 - val_accuracy: 0.9211 - 392ms/epoch - 33ms/step
# Epoch 24/150
# 12/12 - 0s - loss: 0.1079 - accuracy: 0.9560 - val_loss: 0.1541 - val_accuracy: 0.9386 - 390ms/epoch - 32ms/step
# Epoch 25/150
# 12/12 - 0s - loss: 0.1032 - accuracy: 0.9670 - val_loss: 0.2171 - val_accuracy: 0.8947 - 392ms/epoch - 33ms/step
# Epoch 26/150
# 12/12 - 0s - loss: 0.1122 - accuracy: 0.9516 - val_loss: 0.3016 - val_accuracy: 0.8596 - 392ms/epoch - 33ms/step
# Epoch 27/150
# 12/12 - 0s - loss: 0.1201 - accuracy: 0.9495 - val_loss: 1.0861 - val_accuracy: 0.6491 - 388ms/epoch - 32ms/step
# Epoch 28/150
# 12/12 - 0s - loss: 0.1486 - accuracy: 0.9473 - val_loss: 0.1791 - val_accuracy: 0.9211 - 384ms/epoch - 32ms/step
# Epoch 29/150
# 12/12 - 0s - loss: 0.1233 - accuracy: 0.9582 - val_loss: 0.2427 - val_accuracy: 0.8947 - 385ms/epoch - 32ms/step
# Epoch 30/150
# 12/12 - 0s - loss: 0.1123 - accuracy: 0.9538 - val_loss: 0.0792 - val_accuracy: 0.9649 - 387ms/epoch - 32ms/step
# Epoch 31/150
# 12/12 - 0s - loss: 0.1260 - accuracy: 0.9560 - val_loss: 0.0942 - val_accuracy: 0.9649 - 386ms/epoch - 32ms/step
# Epoch 32/150
# 12/12 - 0s - loss: 0.1261 - accuracy: 0.9538 - val_loss: 0.0698 - val_accuracy: 0.9649 - 385ms/epoch - 32ms/step
# Epoch 33/150
# 12/12 - 0s - loss: 0.1006 - accuracy: 0.9582 - val_loss: 0.0728 - val_accuracy: 0.9649 - 392ms/epoch - 33ms/step
# Epoch 34/150
# 12/12 - 0s - loss: 0.1086 - accuracy: 0.9582 - val_loss: 0.1439 - val_accuracy: 0.9474 - 383ms/epoch - 32ms/step
# Epoch 35/150
# 12/12 - 0s - loss: 0.0937 - accuracy: 0.9670 - val_loss: 0.3569 - val_accuracy: 0.8333 - 395ms/epoch - 33ms/step
# Epoch 36/150
# 12/12 - 0s - loss: 0.0946 - accuracy: 0.9626 - val_loss: 0.9603 - val_accuracy: 0.7018 - 392ms/epoch - 33ms/step
# Epoch 37/150
# 12/12 - 0s - loss: 0.1404 - accuracy: 0.9429 - val_loss: 0.0896 - val_accuracy: 0.9474 - 390ms/epoch - 32ms/step
# Epoch 38/150
# 12/12 - 0s - loss: 0.1418 - accuracy: 0.9538 - val_loss: 0.0879 - val_accuracy: 0.9649 - 401ms/epoch - 33ms/step
# Epoch 39/150
# 12/12 - 0s - loss: 0.1231 - accuracy: 0.9538 - val_loss: 0.1019 - val_accuracy: 0.9561 - 396ms/epoch - 33ms/step
# Epoch 40/150
# 12/12 - 0s - loss: 0.1075 - accuracy: 0.9538 - val_loss: 0.2195 - val_accuracy: 0.9211 - 392ms/epoch - 33ms/step
# Epoch 41/150
# 12/12 - 0s - loss: 0.1242 - accuracy: 0.9538 - val_loss: 0.2654 - val_accuracy: 0.9123 - 388ms/epoch - 32ms/step
# Epoch 42/150
# 12/12 - 0s - loss: 0.1105 - accuracy: 0.9538 - val_loss: 0.0658 - val_accuracy: 0.9737 - 393ms/epoch - 33ms/step
# Epoch 43/150
# 12/12 - 0s - loss: 0.1025 - accuracy: 0.9604 - val_loss: 0.0696 - val_accuracy: 0.9649 - 391ms/epoch - 33ms/step
# Epoch 44/150
# 12/12 - 0s - loss: 0.1044 - accuracy: 0.9560 - val_loss: 0.1355 - val_accuracy: 0.9561 - 388ms/epoch - 32ms/step
# Epoch 45/150
# 12/12 - 0s - loss: 0.1171 - accuracy: 0.9495 - val_loss: 0.1374 - val_accuracy: 0.9474 - 402ms/epoch - 33ms/step
# Epoch 46/150
# 12/12 - 0s - loss: 0.1416 - accuracy: 0.9473 - val_loss: 0.1593 - val_accuracy: 0.9298 - 389ms/epoch - 32ms/step
# Epoch 47/150
# 12/12 - 0s - loss: 0.1209 - accuracy: 0.9538 - val_loss: 0.0745 - val_accuracy: 0.9737 - 387ms/epoch - 32ms/step
# Epoch 48/150
# 12/12 - 0s - loss: 0.0895 - accuracy: 0.9538 - val_loss: 0.3576 - val_accuracy: 0.8596 - 394ms/epoch - 33ms/step
# Epoch 49/150
# 12/12 - 0s - loss: 0.0780 - accuracy: 0.9692 - val_loss: 0.1196 - val_accuracy: 0.9474 - 386ms/epoch - 32ms/step
# Epoch 50/150
# 12/12 - 0s - loss: 0.0986 - accuracy: 0.9560 - val_loss: 0.2249 - val_accuracy: 0.9474 - 395ms/epoch - 33ms/step
# Epoch 51/150
# 12/12 - 0s - loss: 0.0956 - accuracy: 0.9714 - val_loss: 0.1237 - val_accuracy: 0.9561 - 397ms/epoch - 33ms/step
# Epoch 52/150
# 12/12 - 0s - loss: 0.1378 - accuracy: 0.9451 - val_loss: 0.1093 - val_accuracy: 0.9561 - 389ms/epoch - 32ms/step
# Epoch 53/150
# 12/12 - 0s - loss: 0.1049 - accuracy: 0.9648 - val_loss: 0.1387 - val_accuracy: 0.9474 - 399ms/epoch - 33ms/step
# Epoch 54/150
# 12/12 - 0s - loss: 0.1026 - accuracy: 0.9648 - val_loss: 0.1336 - val_accuracy: 0.9474 - 393ms/epoch - 33ms/step
# Epoch 55/150
# 12/12 - 0s - loss: 0.1598 - accuracy: 0.9319 - val_loss: 0.2219 - val_accuracy: 0.8772 - 404ms/epoch - 34ms/step
# Epoch 56/150
# 12/12 - 0s - loss: 0.1068 - accuracy: 0.9626 - val_loss: 0.2246 - val_accuracy: 0.8860 - 389ms/epoch - 32ms/step
# Epoch 57/150
# 12/12 - 0s - loss: 0.0958 - accuracy: 0.9670 - val_loss: 0.0852 - val_accuracy: 0.9561 - 393ms/epoch - 33ms/step
# Epoch 58/150
# 12/12 - 0s - loss: 0.1158 - accuracy: 0.9604 - val_loss: 0.1110 - val_accuracy: 0.9561 - 403ms/epoch - 34ms/step
# Epoch 59/150
# 12/12 - 0s - loss: 0.0844 - accuracy: 0.9626 - val_loss: 0.1087 - val_accuracy: 0.9474 - 393ms/epoch - 33ms/step
# Epoch 60/150
# 12/12 - 0s - loss: 0.0892 - accuracy: 0.9648 - val_loss: 0.1041 - val_accuracy: 0.9474 - 388ms/epoch - 32ms/step
# Epoch 61/150
# 12/12 - 0s - loss: 0.1182 - accuracy: 0.9538 - val_loss: 0.2550 - val_accuracy: 0.9035 - 392ms/epoch - 33ms/step
# Epoch 62/150
# 12/12 - 0s - loss: 0.0968 - accuracy: 0.9714 - val_loss: 0.1297 - val_accuracy: 0.9561 - 390ms/epoch - 32ms/step
# Epoch 63/150
# 12/12 - 0s - loss: 0.1073 - accuracy: 0.9648 - val_loss: 0.2417 - val_accuracy: 0.9211 - 397ms/epoch - 33ms/step
# Epoch 64/150
# 12/12 - 0s - loss: 0.0871 - accuracy: 0.9626 - val_loss: 0.1139 - val_accuracy: 0.9649 - 417ms/epoch - 35ms/step
# Epoch 65/150
# 12/12 - 0s - loss: 0.0994 - accuracy: 0.9582 - val_loss: 0.1408 - val_accuracy: 0.9474 - 400ms/epoch - 33ms/step
# Epoch 66/150
# 12/12 - 0s - loss: 0.1051 - accuracy: 0.9604 - val_loss: 0.1097 - val_accuracy: 0.9649 - 391ms/epoch - 33ms/step
# Epoch 67/150
# 12/12 - 0s - loss: 0.0914 - accuracy: 0.9648 - val_loss: 0.1604 - val_accuracy: 0.9386 - 389ms/epoch - 32ms/step
# Epoch 68/150
# 12/12 - 0s - loss: 0.1049 - accuracy: 0.9538 - val_loss: 0.4007 - val_accuracy: 0.8246 - 400ms/epoch - 33ms/step
# Epoch 69/150
# 12/12 - 0s - loss: 0.1231 - accuracy: 0.9451 - val_loss: 0.0771 - val_accuracy: 0.9737 - 388ms/epoch - 32ms/step
# Epoch 70/150
# 12/12 - 0s - loss: 0.1240 - accuracy: 0.9495 - val_loss: 0.1285 - val_accuracy: 0.9474 - 391ms/epoch - 33ms/step
# Epoch 71/150
# 12/12 - 0s - loss: 0.1172 - accuracy: 0.9626 - val_loss: 0.1321 - val_accuracy: 0.9561 - 397ms/epoch - 33ms/step
# Epoch 72/150
# 12/12 - 0s - loss: 0.1067 - accuracy: 0.9604 - val_loss: 0.0720 - val_accuracy: 0.9737 - 388ms/epoch - 32ms/step
# Epoch 73/150
# 12/12 - 0s - loss: 0.1023 - accuracy: 0.9670 - val_loss: 0.0655 - val_accuracy: 0.9737 - 394ms/epoch - 33ms/step
# Epoch 74/150
# 12/12 - 0s - loss: 0.0984 - accuracy: 0.9648 - val_loss: 0.0617 - val_accuracy: 0.9649 - 400ms/epoch - 33ms/step
# Epoch 75/150
# 12/12 - 0s - loss: 0.1073 - accuracy: 0.9582 - val_loss: 0.0585 - val_accuracy: 0.9649 - 388ms/epoch - 32ms/step
# Epoch 76/150
# 12/12 - 0s - loss: 0.0857 - accuracy: 0.9648 - val_loss: 0.0874 - val_accuracy: 0.9649 - 388ms/epoch - 32ms/step
# Epoch 77/150
# 12/12 - 0s - loss: 0.0881 - accuracy: 0.9648 - val_loss: 0.0857 - val_accuracy: 0.9737 - 384ms/epoch - 32ms/step
# Epoch 78/150
# 12/12 - 0s - loss: 0.1004 - accuracy: 0.9560 - val_loss: 0.0816 - val_accuracy: 0.9561 - 393ms/epoch - 33ms/step
# Epoch 79/150
# 12/12 - 0s - loss: 0.0868 - accuracy: 0.9604 - val_loss: 0.0974 - val_accuracy: 0.9737 - 391ms/epoch - 33ms/step
# Epoch 80/150
# 12/12 - 0s - loss: 0.1053 - accuracy: 0.9626 - val_loss: 0.0715 - val_accuracy: 0.9649 - 391ms/epoch - 33ms/step
# Epoch 81/150
# 12/12 - 0s - loss: 0.0877 - accuracy: 0.9626 - val_loss: 0.1100 - val_accuracy: 0.9561 - 390ms/epoch - 33ms/step
# Epoch 82/150
# 12/12 - 0s - loss: 0.0766 - accuracy: 0.9736 - val_loss: 0.1410 - val_accuracy: 0.9561 - 388ms/epoch - 32ms/step
# Epoch 83/150
# 12/12 - 0s - loss: 0.0828 - accuracy: 0.9626 - val_loss: 0.0772 - val_accuracy: 0.9649 - 423ms/epoch - 35ms/step
# Epoch 84/150
# 12/12 - 0s - loss: 0.1014 - accuracy: 0.9582 - val_loss: 0.0664 - val_accuracy: 0.9737 - 392ms/epoch - 33ms/step
# Epoch 85/150
# 12/12 - 0s - loss: 0.1095 - accuracy: 0.9582 - val_loss: 0.1376 - val_accuracy: 0.9561 - 395ms/epoch - 33ms/step
# Epoch 86/150
# 12/12 - 0s - loss: 0.1018 - accuracy: 0.9626 - val_loss: 0.0899 - val_accuracy: 0.9649 - 391ms/epoch - 33ms/step
# Epoch 87/150
# 12/12 - 0s - loss: 0.0892 - accuracy: 0.9626 - val_loss: 0.1726 - val_accuracy: 0.9211 - 384ms/epoch - 32ms/step
# Epoch 88/150
# 12/12 - 0s - loss: 0.0864 - accuracy: 0.9692 - val_loss: 0.2169 - val_accuracy: 0.9298 - 383ms/epoch - 32ms/step
# Epoch 89/150
# 12/12 - 0s - loss: 0.0850 - accuracy: 0.9714 - val_loss: 0.1016 - val_accuracy: 0.9649 - 397ms/epoch - 33ms/step
# Epoch 90/150
# 12/12 - 0s - loss: 0.1131 - accuracy: 0.9604 - val_loss: 0.0787 - val_accuracy: 0.9737 - 387ms/epoch - 32ms/step
# Epoch 91/150
# 12/12 - 0s - loss: 0.1058 - accuracy: 0.9604 - val_loss: 0.0694 - val_accuracy: 0.9737 - 384ms/epoch - 32ms/step
# Epoch 92/150
# 12/12 - 0s - loss: 0.0795 - accuracy: 0.9692 - val_loss: 0.0849 - val_accuracy: 0.9649 - 388ms/epoch - 32ms/step
# Epoch 93/150
# 12/12 - 0s - loss: 0.0763 - accuracy: 0.9670 - val_loss: 0.0701 - val_accuracy: 0.9561 - 429ms/epoch - 36ms/step
# Epoch 94/150
# 12/12 - 0s - loss: 0.0865 - accuracy: 0.9582 - val_loss: 0.0759 - val_accuracy: 0.9649 - 390ms/epoch - 32ms/step
# Epoch 95/150
# 12/12 - 0s - loss: 0.0985 - accuracy: 0.9648 - val_loss: 0.1396 - val_accuracy: 0.9561 - 387ms/epoch - 32ms/step
# Epoch 96/150
# 12/12 - 0s - loss: 0.1297 - accuracy: 0.9538 - val_loss: 0.0738 - val_accuracy: 0.9649 - 390ms/epoch - 33ms/step
# Epoch 97/150
# 12/12 - 0s - loss: 0.0856 - accuracy: 0.9582 - val_loss: 0.0740 - val_accuracy: 0.9561 - 388ms/epoch - 32ms/step
# Epoch 98/150
# 12/12 - 0s - loss: 0.0865 - accuracy: 0.9670 - val_loss: 0.0787 - val_accuracy: 0.9649 - 391ms/epoch - 33ms/step
# Epoch 99/150
# 12/12 - 0s - loss: 0.0866 - accuracy: 0.9648 - val_loss: 0.1638 - val_accuracy: 0.9474 - 395ms/epoch - 33ms/step
# Epoch 100/150
# 12/12 - 0s - loss: 0.0797 - accuracy: 0.9648 - val_loss: 0.1388 - val_accuracy: 0.9474 - 396ms/epoch - 33ms/step
# Epoch 101/150
# 12/12 - 0s - loss: 0.1145 - accuracy: 0.9604 - val_loss: 0.0823 - val_accuracy: 0.9649 - 396ms/epoch - 33ms/step
# Epoch 102/150
# 12/12 - 0s - loss: 0.0832 - accuracy: 0.9714 - val_loss: 0.0713 - val_accuracy: 0.9649 - 419ms/epoch - 35ms/step
# Epoch 103/150
# 12/12 - 0s - loss: 0.0841 - accuracy: 0.9582 - val_loss: 0.0621 - val_accuracy: 0.9737 - 387ms/epoch - 32ms/step
# Epoch 104/150
# 12/12 - 0s - loss: 0.0852 - accuracy: 0.9692 - val_loss: 0.0998 - val_accuracy: 0.9561 - 395ms/epoch - 33ms/step
# Epoch 105/150
# 12/12 - 0s - loss: 0.0894 - accuracy: 0.9670 - val_loss: 0.1657 - val_accuracy: 0.9474 - 420ms/epoch - 35ms/step
# Epoch 106/150
# 12/12 - 0s - loss: 0.0946 - accuracy: 0.9626 - val_loss: 0.0864 - val_accuracy: 0.9649 - 400ms/epoch - 33ms/step
# Epoch 107/150
# 12/12 - 0s - loss: 0.1128 - accuracy: 0.9451 - val_loss: 0.0699 - val_accuracy: 0.9649 - 390ms/epoch - 33ms/step
# Epoch 108/150
# 12/12 - 0s - loss: 0.0909 - accuracy: 0.9626 - val_loss: 0.0770 - val_accuracy: 0.9737 - 396ms/epoch - 33ms/step
# Epoch 109/150
# 12/12 - 0s - loss: 0.0882 - accuracy: 0.9648 - val_loss: 0.0738 - val_accuracy: 0.9649 - 393ms/epoch - 33ms/step
# Epoch 110/150
# 12/12 - 0s - loss: 0.0891 - accuracy: 0.9604 - val_loss: 0.0704 - val_accuracy: 0.9649 - 387ms/epoch - 32ms/step
# Epoch 111/150
# 12/12 - 0s - loss: 0.0755 - accuracy: 0.9670 - val_loss: 0.0673 - val_accuracy: 0.9737 - 389ms/epoch - 32ms/step
# Epoch 112/150
# 12/12 - 0s - loss: 0.0997 - accuracy: 0.9560 - val_loss: 0.1039 - val_accuracy: 0.9737 - 396ms/epoch - 33ms/step
# Epoch 113/150
# 12/12 - 0s - loss: 0.0905 - accuracy: 0.9582 - val_loss: 0.0707 - val_accuracy: 0.9649 - 461ms/epoch - 38ms/step
# Epoch 114/150
# 12/12 - 0s - loss: 0.0779 - accuracy: 0.9626 - val_loss: 0.1464 - val_accuracy: 0.9561 - 411ms/epoch - 34ms/step
# Epoch 115/150
# 12/12 - 0s - loss: 0.0768 - accuracy: 0.9648 - val_loss: 0.0908 - val_accuracy: 0.9649 - 392ms/epoch - 33ms/step
# Epoch 116/150
# 12/12 - 0s - loss: 0.0740 - accuracy: 0.9692 - val_loss: 0.0942 - val_accuracy: 0.9649 - 399ms/epoch - 33ms/step
# Epoch 117/150
# 12/12 - 0s - loss: 0.0603 - accuracy: 0.9714 - val_loss: 0.1025 - val_accuracy: 0.9649 - 388ms/epoch - 32ms/step
# Epoch 118/150
# 12/12 - 0s - loss: 0.1043 - accuracy: 0.9626 - val_loss: 0.0738 - val_accuracy: 0.9649 - 401ms/epoch - 33ms/step
# Epoch 119/150
# 12/12 - 0s - loss: 0.1184 - accuracy: 0.9560 - val_loss: 0.1637 - val_accuracy: 0.9737 - 390ms/epoch - 32ms/step
# Epoch 120/150
# 12/12 - 0s - loss: 0.1159 - accuracy: 0.9604 - val_loss: 0.1788 - val_accuracy: 0.9474 - 392ms/epoch - 33ms/step
# Epoch 121/150
# 12/12 - 0s - loss: 0.1187 - accuracy: 0.9538 - val_loss: 0.1011 - val_accuracy: 0.9561 - 395ms/epoch - 33ms/step
# Epoch 122/150
# 12/12 - 0s - loss: 0.0777 - accuracy: 0.9692 - val_loss: 0.0713 - val_accuracy: 0.9737 - 393ms/epoch - 33ms/step
# Epoch 123/150
# 12/12 - 0s - loss: 0.0816 - accuracy: 0.9648 - val_loss: 0.0819 - val_accuracy: 0.9737 - 390ms/epoch - 32ms/step
# Epoch 124/150
# 12/12 - 0s - loss: 0.0908 - accuracy: 0.9626 - val_loss: 0.0960 - val_accuracy: 0.9649 - 390ms/epoch - 32ms/step
# Epoch 125/150
# 12/12 - 0s - loss: 0.0692 - accuracy: 0.9736 - val_loss: 0.1096 - val_accuracy: 0.9561 - 427ms/epoch - 36ms/step
# Epoch 126/150
# 12/12 - 0s - loss: 0.0767 - accuracy: 0.9758 - val_loss: 0.1068 - val_accuracy: 0.9649 - 419ms/epoch - 35ms/step
# Epoch 127/150
# 12/12 - 0s - loss: 0.0990 - accuracy: 0.9604 - val_loss: 0.1539 - val_accuracy: 0.9298 - 389ms/epoch - 32ms/step
# Epoch 128/150
# 12/12 - 0s - loss: 0.0911 - accuracy: 0.9604 - val_loss: 0.1950 - val_accuracy: 0.9298 - 389ms/epoch - 32ms/step
# Epoch 129/150
# 12/12 - 0s - loss: 0.1009 - accuracy: 0.9604 - val_loss: 1.1100 - val_accuracy: 0.7544 - 390ms/epoch - 32ms/step
# Epoch 130/150
# 12/12 - 0s - loss: 0.0876 - accuracy: 0.9604 - val_loss: 0.0956 - val_accuracy: 0.9474 - 393ms/epoch - 33ms/step
# Epoch 131/150
# 12/12 - 0s - loss: 0.0802 - accuracy: 0.9604 - val_loss: 0.0824 - val_accuracy: 0.9649 - 417ms/epoch - 35ms/step
# Epoch 132/150
# 12/12 - 0s - loss: 0.0798 - accuracy: 0.9692 - val_loss: 0.1693 - val_accuracy: 0.9386 - 388ms/epoch - 32ms/step
# Epoch 133/150
# 12/12 - 0s - loss: 0.0876 - accuracy: 0.9648 - val_loss: 2.0488 - val_accuracy: 0.5877 - 388ms/epoch - 32ms/step
# Epoch 134/150
# 12/12 - 0s - loss: 0.0652 - accuracy: 0.9692 - val_loss: 0.0550 - val_accuracy: 0.9561 - 392ms/epoch - 33ms/step
# Epoch 135/150
# 12/12 - 0s - loss: 0.0700 - accuracy: 0.9736 - val_loss: 0.0656 - val_accuracy: 0.9737 - 389ms/epoch - 32ms/step
# Epoch 136/150
# 12/12 - 0s - loss: 0.0765 - accuracy: 0.9692 - val_loss: 0.1688 - val_accuracy: 0.9561 - 399ms/epoch - 33ms/step
# Epoch 137/150
# 12/12 - 0s - loss: 0.0759 - accuracy: 0.9670 - val_loss: 0.1692 - val_accuracy: 0.9561 - 392ms/epoch - 33ms/step
# Epoch 138/150
# 12/12 - 0s - loss: 0.0705 - accuracy: 0.9758 - val_loss: 0.1430 - val_accuracy: 0.9561 - 393ms/epoch - 33ms/step
# Epoch 139/150
# 12/12 - 0s - loss: 0.0699 - accuracy: 0.9714 - val_loss: 0.0973 - val_accuracy: 0.9737 - 389ms/epoch - 32ms/step
# Epoch 140/150
# 12/12 - 0s - loss: 0.0883 - accuracy: 0.9714 - val_loss: 0.1202 - val_accuracy: 0.9649 - 395ms/epoch - 33ms/step
# Epoch 141/150
# 12/12 - 0s - loss: 0.0821 - accuracy: 0.9604 - val_loss: 0.1556 - val_accuracy: 0.9474 - 390ms/epoch - 33ms/step
# Epoch 142/150
# 12/12 - 0s - loss: 0.0882 - accuracy: 0.9604 - val_loss: 0.0987 - val_accuracy: 0.9561 - 399ms/epoch - 33ms/step
# Epoch 143/150
# 12/12 - 0s - loss: 0.0832 - accuracy: 0.9604 - val_loss: 0.0851 - val_accuracy: 0.9649 - 392ms/epoch - 33ms/step
# Epoch 144/150
# 12/12 - 0s - loss: 0.0851 - accuracy: 0.9692 - val_loss: 0.0865 - val_accuracy: 0.9561 - 422ms/epoch - 35ms/step
# Epoch 145/150
# 12/12 - 0s - loss: 0.0787 - accuracy: 0.9714 - val_loss: 0.0738 - val_accuracy: 0.9561 - 427ms/epoch - 36ms/step
# Epoch 146/150
# 12/12 - 0s - loss: 0.0743 - accuracy: 0.9714 - val_loss: 0.0819 - val_accuracy: 0.9737 - 416ms/epoch - 35ms/step
# Epoch 147/150
# 12/12 - 0s - loss: 0.0706 - accuracy: 0.9714 - val_loss: 0.3124 - val_accuracy: 0.8947 - 390ms/epoch - 32ms/step
# Epoch 148/150
# 12/12 - 0s - loss: 0.0861 - accuracy: 0.9692 - val_loss: 0.1270 - val_accuracy: 0.9561 - 393ms/epoch - 33ms/step
# Epoch 149/150
# 12/12 - 0s - loss: 0.1231 - accuracy: 0.9473 - val_loss: 0.1037 - val_accuracy: 0.9561 - 397ms/epoch - 33ms/step
# Epoch 150/150
# 12/12 - 0s - loss: 0.0736 - accuracy: 0.9736 - val_loss: 0.0987 - val_accuracy: 0.9474 - 390ms/epoch - 33ms/step

# %%
# plot the loss, acc graph
plot_history(hist_gru)

# %% [markdown]
# #### Test GRU model

# %%
# Evaluate the model..
loss, acc = model_GRU.evaluate(X_test, Y_test_oh)
print()
print("Test accuracy = ", acc)
# Out:
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0987 - accuracy: 0.9474
#
# Test accuracy =  0.9473684430122375

# %%
gru_pred = model_GRU.predict(X_test)

# %%
# save the model here...
#model_GRU.save('Breast_cancer_GRU_model.h5')

# %%
# Get the confusion matrix values.
True_Positives,False_Positives,False_Negetives,True_Negetives = get_confusion_matrix(Y_test_oh,gru_pred)

# %%
pre,rec,spe = get_cm_components(True_Positives,False_Positives,False_Negetives,True_Negetives)

# %%
# view model acc, precision, recall etc..
vals = {'Accuracy':acc,'Precision':pre,'Recall':rec,'Specificity':spe}
data = pd.DataFrame(vals, index= ["GRU"])
summary_table = pd.concat([summary_table,data])
summary_table
# Out:
#            Accuracy  Precision    Recall  Specificity
# LSTM       0.973684   0.958333  1.000000     0.933333
# SimpleRNN  0.964912   0.972222  0.972222     0.952381

# %% [markdown]
# ### With RNN model

# %%
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam,RMSprop,Adadelta
from tensorflow.keras.layers import SimpleRNN, Activation, Dense, Dropout, Input, BatchNormalization
import tensorflow as tf

# %%
# Model

data = Input((X_train.shape[1],1),dtype= 'float32')  # Input layer

X = SimpleRNN(128, return_sequences= True)(data)
#X = BatchNormalization()(X)
X = Dropout(0.5)(X)
X = SimpleRNN(128,return_sequences = True)(X)
#X = BatchNormalization()(X)
X = Dropout(0.5)(X)
X = SimpleRNN(64,return_sequences = False)(X)
#X = BatchNormalization()(X)
#X = Dropout(0.5)(X)
X = Dense(units=4)(X)
X = Dense(units=2)(X)
# use sigmoid
X = Activation('sigmoid')(X)   # sigmoid is for binary classification and softmax for multiclass classification.
model_RNN = Model(data, X)

# %%
model_RNN.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 30, 1)]           0
#
#  simple_rnn (SimpleRNN)      (None, 30, 128)           16640
#
#  dropout_4 (Dropout)         (None, 30, 128)           0
#
#  simple_rnn_1 (SimpleRNN)    (None, 30, 128)           32896
#
#  dropout_5 (Dropout)         (None, 30, 128)           0
#
#  simple_rnn_2 (SimpleRNN)    (None, 64)                12352
#
#  dense_4 (Dense)             (None, 4)                 260
#
#  dense_5 (Dense)             (None, 2)                 10
#
#  activation_2 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 62,158
# Trainable params: 62,158
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_RNN.compile(optimizer= RMSprop(learning_rate= 0.001), loss= 'binary_crossentropy', metrics=['accuracy'])

# %%
hist_rnn = model_RNN.fit(X_train, Y_train_oh, epochs= 250, batch_size = 40, shuffle=True, verbose = 2,validation_data = (X_test,Y_test_oh))
# Out:
# Epoch 1/250
# 12/12 - 5s - loss: 0.7368 - accuracy: 0.6154 - val_loss: 0.6515 - val_accuracy: 0.6316 - 5s/epoch - 407ms/step
# Epoch 2/250
# 12/12 - 2s - loss: 0.6840 - accuracy: 0.6198 - val_loss: 0.6398 - val_accuracy: 0.6316 - 2s/epoch - 125ms/step
# Epoch 3/250
# 12/12 - 2s - loss: 0.6603 - accuracy: 0.6286 - val_loss: 0.7015 - val_accuracy: 0.3684 - 2s/epoch - 128ms/step
# Epoch 4/250
# 12/12 - 2s - loss: 0.6541 - accuracy: 0.6374 - val_loss: 0.7629 - val_accuracy: 0.3684 - 2s/epoch - 130ms/step
# Epoch 5/250
# 12/12 - 2s - loss: 0.6678 - accuracy: 0.6198 - val_loss: 0.7972 - val_accuracy: 0.6316 - 2s/epoch - 130ms/step
# Epoch 6/250
# 12/12 - 2s - loss: 0.6581 - accuracy: 0.6132 - val_loss: 0.6055 - val_accuracy: 0.6316 - 2s/epoch - 129ms/step
# Epoch 7/250
# 12/12 - 1s - loss: 0.6737 - accuracy: 0.6154 - val_loss: 0.7549 - val_accuracy: 0.3684 - 1s/epoch - 123ms/step
# Epoch 8/250
# 12/12 - 2s - loss: 0.6189 - accuracy: 0.6418 - val_loss: 0.4683 - val_accuracy: 0.8596 - 2s/epoch - 130ms/step
# Epoch 9/250
# 12/12 - 2s - loss: 0.6440 - accuracy: 0.6725 - val_loss: 0.4952 - val_accuracy: 0.7105 - 2s/epoch - 128ms/step
# Epoch 10/250
# 12/12 - 2s - loss: 0.5159 - accuracy: 0.7956 - val_loss: 0.9599 - val_accuracy: 0.4561 - 2s/epoch - 130ms/step
# Epoch 11/250
# 12/12 - 2s - loss: 0.5549 - accuracy: 0.7341 - val_loss: 0.2844 - val_accuracy: 0.8947 - 2s/epoch - 131ms/step
# Epoch 12/250
# 12/12 - 2s - loss: 0.4557 - accuracy: 0.8022 - val_loss: 0.2065 - val_accuracy: 0.9386 - 2s/epoch - 130ms/step
# Epoch 13/250
# 12/12 - 2s - loss: 0.3949 - accuracy: 0.8440 - val_loss: 0.5423 - val_accuracy: 0.7632 - 2s/epoch - 128ms/step
# Epoch 14/250
# 12/12 - 2s - loss: 0.3143 - accuracy: 0.8791 - val_loss: 0.4768 - val_accuracy: 0.8246 - 2s/epoch - 125ms/step
# Epoch 15/250
# 12/12 - 1s - loss: 0.3593 - accuracy: 0.8637 - val_loss: 0.2744 - val_accuracy: 0.8772 - 1s/epoch - 125ms/step
# Epoch 16/250
# 12/12 - 2s - loss: 0.2667 - accuracy: 0.9121 - val_loss: 0.9261 - val_accuracy: 0.7105 - 2s/epoch - 125ms/step
# Epoch 17/250
# 12/12 - 1s - loss: 0.3367 - accuracy: 0.8703 - val_loss: 0.6518 - val_accuracy: 0.7456 - 1s/epoch - 121ms/step
# Epoch 18/250
# 12/12 - 2s - loss: 0.3063 - accuracy: 0.8945 - val_loss: 0.1587 - val_accuracy: 0.9474 - 2s/epoch - 126ms/step
# Epoch 19/250
# 12/12 - 1s - loss: 0.2626 - accuracy: 0.9165 - val_loss: 0.5098 - val_accuracy: 0.8158 - 1s/epoch - 120ms/step
# Epoch 20/250
# 12/12 - 2s - loss: 0.2998 - accuracy: 0.8923 - val_loss: 0.1999 - val_accuracy: 0.9123 - 2s/epoch - 129ms/step
# Epoch 21/250
# 12/12 - 1s - loss: 0.2345 - accuracy: 0.9209 - val_loss: 0.8423 - val_accuracy: 0.7368 - 1s/epoch - 125ms/step
# Epoch 22/250
# 12/12 - 2s - loss: 0.3179 - accuracy: 0.8857 - val_loss: 0.1356 - val_accuracy: 0.9561 - 2s/epoch - 130ms/step
# Epoch 23/250
# 12/12 - 2s - loss: 0.2604 - accuracy: 0.9033 - val_loss: 0.0806 - val_accuracy: 0.9912 - 2s/epoch - 130ms/step
# Epoch 24/250
# 12/12 - 1s - loss: 0.2697 - accuracy: 0.9033 - val_loss: 0.3509 - val_accuracy: 0.8684 - 1s/epoch - 122ms/step
# Epoch 25/250
# 12/12 - 1s - loss: 0.3035 - accuracy: 0.8945 - val_loss: 0.5727 - val_accuracy: 0.8070 - 1s/epoch - 122ms/step
# Epoch 26/250
# 12/12 - 1s - loss: 0.2249 - accuracy: 0.9077 - val_loss: 0.1248 - val_accuracy: 0.9561 - 1s/epoch - 121ms/step
# Epoch 27/250
# 12/12 - 2s - loss: 0.2072 - accuracy: 0.9275 - val_loss: 0.1867 - val_accuracy: 0.9211 - 2s/epoch - 129ms/step
# Epoch 28/250
# 12/12 - 2s - loss: 0.2366 - accuracy: 0.9099 - val_loss: 0.2203 - val_accuracy: 0.9035 - 2s/epoch - 127ms/step
# Epoch 29/250
# 12/12 - 1s - loss: 0.2447 - accuracy: 0.9077 - val_loss: 0.2226 - val_accuracy: 0.9123 - 1s/epoch - 123ms/step
# Epoch 30/250
# 12/12 - 2s - loss: 0.2512 - accuracy: 0.9033 - val_loss: 0.1130 - val_accuracy: 0.9737 - 2s/epoch - 131ms/step
# Epoch 31/250
# 12/12 - 2s - loss: 0.2540 - accuracy: 0.8901 - val_loss: 0.1915 - val_accuracy: 0.9123 - 2s/epoch - 134ms/step
# Epoch 32/250
# 12/12 - 2s - loss: 0.2582 - accuracy: 0.9055 - val_loss: 0.3224 - val_accuracy: 0.8772 - 2s/epoch - 141ms/step
# Epoch 33/250
# 12/12 - 2s - loss: 0.1990 - accuracy: 0.9231 - val_loss: 0.0662 - val_accuracy: 0.9737 - 2s/epoch - 128ms/step
# Epoch 34/250
# 12/12 - 2s - loss: 0.1811 - accuracy: 0.9363 - val_loss: 0.0700 - val_accuracy: 0.9912 - 2s/epoch - 127ms/step
# Epoch 35/250
# 12/12 - 2s - loss: 0.1973 - accuracy: 0.9363 - val_loss: 0.2016 - val_accuracy: 0.9474 - 2s/epoch - 126ms/step
# Epoch 36/250
# 12/12 - 2s - loss: 0.2981 - accuracy: 0.8791 - val_loss: 0.1168 - val_accuracy: 0.9649 - 2s/epoch - 132ms/step
# Epoch 37/250
# 12/12 - 2s - loss: 0.2052 - accuracy: 0.9297 - val_loss: 0.1958 - val_accuracy: 0.9298 - 2s/epoch - 127ms/step
# Epoch 38/250
# 12/12 - 2s - loss: 0.1901 - accuracy: 0.9385 - val_loss: 0.2344 - val_accuracy: 0.8860 - 2s/epoch - 128ms/step
# Epoch 39/250
# 12/12 - 2s - loss: 0.1766 - accuracy: 0.9407 - val_loss: 0.1945 - val_accuracy: 0.9123 - 2s/epoch - 127ms/step
# Epoch 40/250
# 12/12 - 2s - loss: 0.2617 - accuracy: 0.9011 - val_loss: 0.0595 - val_accuracy: 0.9737 - 2s/epoch - 126ms/step
# Epoch 41/250
# 12/12 - 2s - loss: 0.2089 - accuracy: 0.9143 - val_loss: 0.1118 - val_accuracy: 0.9474 - 2s/epoch - 126ms/step
# Epoch 42/250
# 12/12 - 2s - loss: 0.1761 - accuracy: 0.9363 - val_loss: 0.0910 - val_accuracy: 0.9737 - 2s/epoch - 128ms/step
# Epoch 43/250
# 12/12 - 1s - loss: 0.2433 - accuracy: 0.9033 - val_loss: 0.1031 - val_accuracy: 0.9737 - 1s/epoch - 124ms/step
# Epoch 44/250
# 12/12 - 2s - loss: 0.2069 - accuracy: 0.9165 - val_loss: 0.1649 - val_accuracy: 0.9649 - 2s/epoch - 129ms/step
# Epoch 45/250
# 12/12 - 2s - loss: 0.1836 - accuracy: 0.9297 - val_loss: 0.2179 - val_accuracy: 0.8772 - 2s/epoch - 132ms/step
# Epoch 46/250
# 12/12 - 2s - loss: 0.1930 - accuracy: 0.9385 - val_loss: 0.1534 - val_accuracy: 0.9386 - 2s/epoch - 136ms/step
# Epoch 47/250
# 12/12 - 2s - loss: 0.2134 - accuracy: 0.9143 - val_loss: 0.0940 - val_accuracy: 0.9737 - 2s/epoch - 128ms/step
# Epoch 48/250
# 12/12 - 2s - loss: 0.2149 - accuracy: 0.9209 - val_loss: 0.1534 - val_accuracy: 0.9649 - 2s/epoch - 128ms/step
# Epoch 49/250
# 12/12 - 2s - loss: 0.1829 - accuracy: 0.9363 - val_loss: 0.4699 - val_accuracy: 0.7807 - 2s/epoch - 127ms/step
# Epoch 50/250
# 12/12 - 2s - loss: 0.1644 - accuracy: 0.9407 - val_loss: 0.1049 - val_accuracy: 0.9737 - 2s/epoch - 132ms/step
# Epoch 51/250
# 12/12 - 2s - loss: 0.1779 - accuracy: 0.9429 - val_loss: 0.2382 - val_accuracy: 0.9123 - 2s/epoch - 132ms/step
# Epoch 52/250
# 12/12 - 2s - loss: 0.2128 - accuracy: 0.9275 - val_loss: 0.2543 - val_accuracy: 0.8860 - 2s/epoch - 132ms/step
# Epoch 53/250
# 12/12 - 2s - loss: 0.1977 - accuracy: 0.9231 - val_loss: 0.1020 - val_accuracy: 0.9912 - 2s/epoch - 126ms/step
# Epoch 54/250
# 12/12 - 2s - loss: 0.1297 - accuracy: 0.9538 - val_loss: 0.0572 - val_accuracy: 0.9825 - 2s/epoch - 136ms/step
# Epoch 55/250
# 12/12 - 2s - loss: 0.1926 - accuracy: 0.9363 - val_loss: 0.2310 - val_accuracy: 0.8947 - 2s/epoch - 138ms/step
# Epoch 56/250
# 12/12 - 2s - loss: 0.1810 - accuracy: 0.9319 - val_loss: 0.7647 - val_accuracy: 0.7544 - 2s/epoch - 131ms/step
# Epoch 57/250
# 12/12 - 2s - loss: 0.2495 - accuracy: 0.8945 - val_loss: 0.0735 - val_accuracy: 0.9737 - 2s/epoch - 128ms/step
# Epoch 58/250
# 12/12 - 2s - loss: 0.1551 - accuracy: 0.9495 - val_loss: 0.1509 - val_accuracy: 0.9298 - 2s/epoch - 125ms/step
# Epoch 59/250
# 12/12 - 2s - loss: 0.1880 - accuracy: 0.9253 - val_loss: 0.1366 - val_accuracy: 0.9561 - 2s/epoch - 128ms/step
# Epoch 60/250
# 12/12 - 2s - loss: 0.1723 - accuracy: 0.9385 - val_loss: 0.0943 - val_accuracy: 0.9737 - 2s/epoch - 131ms/step
# Epoch 61/250
# 12/12 - 2s - loss: 0.1934 - accuracy: 0.9275 - val_loss: 0.0903 - val_accuracy: 0.9825 - 2s/epoch - 138ms/step
# Epoch 62/250
# 12/12 - 2s - loss: 0.1710 - accuracy: 0.9319 - val_loss: 0.0795 - val_accuracy: 0.9825 - 2s/epoch - 140ms/step
# Epoch 63/250
# 12/12 - 2s - loss: 0.1930 - accuracy: 0.9275 - val_loss: 0.1310 - val_accuracy: 0.9825 - 2s/epoch - 137ms/step
# Epoch 64/250
# 12/12 - 2s - loss: 0.1540 - accuracy: 0.9473 - val_loss: 0.4960 - val_accuracy: 0.8246 - 2s/epoch - 134ms/step
# Epoch 65/250
# 12/12 - 2s - loss: 0.1661 - accuracy: 0.9495 - val_loss: 0.0995 - val_accuracy: 0.9649 - 2s/epoch - 133ms/step
# Epoch 66/250
# 12/12 - 1s - loss: 0.1973 - accuracy: 0.9231 - val_loss: 0.2847 - val_accuracy: 0.8509 - 1s/epoch - 123ms/step
# Epoch 67/250
# 12/12 - 2s - loss: 0.1585 - accuracy: 0.9495 - val_loss: 0.0592 - val_accuracy: 0.9737 - 2s/epoch - 132ms/step
# Epoch 68/250
# 12/12 - 2s - loss: 0.2106 - accuracy: 0.9165 - val_loss: 0.1081 - val_accuracy: 0.9649 - 2s/epoch - 134ms/step
# Epoch 69/250
# 12/12 - 2s - loss: 0.1435 - accuracy: 0.9560 - val_loss: 0.1674 - val_accuracy: 0.9211 - 2s/epoch - 132ms/step
# Epoch 70/250
# 12/12 - 2s - loss: 0.1705 - accuracy: 0.9319 - val_loss: 0.1373 - val_accuracy: 0.9298 - 2s/epoch - 134ms/step
# Epoch 71/250
# 12/12 - 2s - loss: 0.1814 - accuracy: 0.9275 - val_loss: 0.0444 - val_accuracy: 0.9912 - 2s/epoch - 131ms/step
# Epoch 72/250
# 12/12 - 1s - loss: 0.1778 - accuracy: 0.9429 - val_loss: 0.1940 - val_accuracy: 0.9474 - 1s/epoch - 125ms/step
# Epoch 73/250
# 12/12 - 2s - loss: 0.1866 - accuracy: 0.9363 - val_loss: 0.1276 - val_accuracy: 0.9825 - 2s/epoch - 130ms/step
# Epoch 74/250
# 12/12 - 2s - loss: 0.1542 - accuracy: 0.9429 - val_loss: 0.1900 - val_accuracy: 0.9298 - 2s/epoch - 133ms/step
# Epoch 75/250
# 12/12 - 2s - loss: 0.1979 - accuracy: 0.9341 - val_loss: 0.2519 - val_accuracy: 0.9123 - 2s/epoch - 130ms/step
# Epoch 76/250
# 12/12 - 2s - loss: 0.1524 - accuracy: 0.9473 - val_loss: 0.0847 - val_accuracy: 0.9737 - 2s/epoch - 131ms/step
# Epoch 77/250
# 12/12 - 2s - loss: 0.1846 - accuracy: 0.9341 - val_loss: 0.1435 - val_accuracy: 0.9561 - 2s/epoch - 139ms/step
# Epoch 78/250
# 12/12 - 2s - loss: 0.1879 - accuracy: 0.9275 - val_loss: 0.1067 - val_accuracy: 0.9825 - 2s/epoch - 134ms/step
# Epoch 79/250
# 12/12 - 2s - loss: 0.1640 - accuracy: 0.9341 - val_loss: 0.0631 - val_accuracy: 0.9825 - 2s/epoch - 136ms/step
# Epoch 80/250
# 12/12 - 2s - loss: 0.1341 - accuracy: 0.9516 - val_loss: 0.0576 - val_accuracy: 1.0000 - 2s/epoch - 138ms/step
# Epoch 81/250
# 12/12 - 2s - loss: 0.1744 - accuracy: 0.9341 - val_loss: 0.0832 - val_accuracy: 0.9737 - 2s/epoch - 131ms/step
# Epoch 82/250
# 12/12 - 2s - loss: 0.1607 - accuracy: 0.9495 - val_loss: 0.2657 - val_accuracy: 0.9386 - 2s/epoch - 131ms/step
# Epoch 83/250
# 12/12 - 2s - loss: 0.1819 - accuracy: 0.9451 - val_loss: 0.0757 - val_accuracy: 0.9737 - 2s/epoch - 133ms/step
# Epoch 84/250
# 12/12 - 2s - loss: 0.1883 - accuracy: 0.9165 - val_loss: 0.0602 - val_accuracy: 0.9912 - 2s/epoch - 131ms/step
# Epoch 85/250
# 12/12 - 2s - loss: 0.1393 - accuracy: 0.9473 - val_loss: 0.0896 - val_accuracy: 0.9825 - 2s/epoch - 134ms/step
# Epoch 86/250
# 12/12 - 2s - loss: 0.1778 - accuracy: 0.9209 - val_loss: 0.1185 - val_accuracy: 0.9298 - 2s/epoch - 135ms/step
# Epoch 87/250
# 12/12 - 2s - loss: 0.1563 - accuracy: 0.9297 - val_loss: 0.0551 - val_accuracy: 0.9737 - 2s/epoch - 133ms/step
# Epoch 88/250
# 12/12 - 2s - loss: 0.1602 - accuracy: 0.9385 - val_loss: 0.1087 - val_accuracy: 0.9649 - 2s/epoch - 131ms/step
# Epoch 89/250
# 12/12 - 1s - loss: 0.1845 - accuracy: 0.9363 - val_loss: 0.0548 - val_accuracy: 0.9737 - 1s/epoch - 121ms/step
# Epoch 90/250
# 12/12 - 1s - loss: 0.1482 - accuracy: 0.9429 - val_loss: 0.0905 - val_accuracy: 0.9825 - 1s/epoch - 124ms/step
# Epoch 91/250
# 12/12 - 2s - loss: 0.1489 - accuracy: 0.9451 - val_loss: 0.1458 - val_accuracy: 0.9649 - 2s/epoch - 128ms/step
# Epoch 92/250
# 12/12 - 2s - loss: 0.1923 - accuracy: 0.9297 - val_loss: 0.0980 - val_accuracy: 0.9912 - 2s/epoch - 130ms/step
# Epoch 93/250
# 12/12 - 2s - loss: 0.1307 - accuracy: 0.9582 - val_loss: 0.0742 - val_accuracy: 0.9825 - 2s/epoch - 127ms/step
# Epoch 94/250
# 12/12 - 2s - loss: 0.1804 - accuracy: 0.9341 - val_loss: 0.0772 - val_accuracy: 0.9912 - 2s/epoch - 126ms/step
# Epoch 95/250
# 12/12 - 2s - loss: 0.1737 - accuracy: 0.9385 - val_loss: 0.1054 - val_accuracy: 0.9649 - 2s/epoch - 132ms/step
# Epoch 96/250
# 12/12 - 1s - loss: 0.1817 - accuracy: 0.9429 - val_loss: 0.2460 - val_accuracy: 0.9474 - 1s/epoch - 121ms/step
# Epoch 97/250
# 12/12 - 2s - loss: 0.1460 - accuracy: 0.9560 - val_loss: 0.1559 - val_accuracy: 0.9561 - 2s/epoch - 129ms/step
# Epoch 98/250
# 12/12 - 2s - loss: 0.2092 - accuracy: 0.9275 - val_loss: 0.1240 - val_accuracy: 0.9561 - 2s/epoch - 128ms/step
# Epoch 99/250
# 12/12 - 2s - loss: 0.1314 - accuracy: 0.9473 - val_loss: 0.1023 - val_accuracy: 0.9649 - 2s/epoch - 137ms/step
# Epoch 100/250
# 12/12 - 2s - loss: 0.1876 - accuracy: 0.9363 - val_loss: 0.1040 - val_accuracy: 0.9561 - 2s/epoch - 129ms/step
# Epoch 101/250
# 12/12 - 2s - loss: 0.1587 - accuracy: 0.9385 - val_loss: 0.1166 - val_accuracy: 0.9825 - 2s/epoch - 130ms/step
# Epoch 102/250
# 12/12 - 1s - loss: 0.1435 - accuracy: 0.9473 - val_loss: 0.1731 - val_accuracy: 0.9211 - 1s/epoch - 118ms/step
# Epoch 103/250
# 12/12 - 1s - loss: 0.1647 - accuracy: 0.9429 - val_loss: 0.0637 - val_accuracy: 0.9737 - 1s/epoch - 125ms/step
# Epoch 104/250
# 12/12 - 2s - loss: 0.1652 - accuracy: 0.9385 - val_loss: 0.1290 - val_accuracy: 0.9211 - 2s/epoch - 129ms/step
# Epoch 105/250
# 12/12 - 1s - loss: 0.1592 - accuracy: 0.9451 - val_loss: 0.0900 - val_accuracy: 0.9825 - 1s/epoch - 122ms/step
# Epoch 106/250
# 12/12 - 2s - loss: 0.1579 - accuracy: 0.9516 - val_loss: 0.0648 - val_accuracy: 0.9825 - 2s/epoch - 126ms/step
# Epoch 107/250
# 12/12 - 2s - loss: 0.1747 - accuracy: 0.9341 - val_loss: 0.1786 - val_accuracy: 0.9386 - 2s/epoch - 133ms/step
# Epoch 108/250
# 12/12 - 2s - loss: 0.1673 - accuracy: 0.9473 - val_loss: 0.0676 - val_accuracy: 0.9825 - 2s/epoch - 128ms/step
# Epoch 109/250
# 12/12 - 2s - loss: 0.1377 - accuracy: 0.9516 - val_loss: 0.0638 - val_accuracy: 0.9825 - 2s/epoch - 128ms/step
# Epoch 110/250
# 12/12 - 2s - loss: 0.1464 - accuracy: 0.9451 - val_loss: 0.1166 - val_accuracy: 0.9298 - 2s/epoch - 127ms/step
# Epoch 111/250
# 12/12 - 1s - loss: 0.1638 - accuracy: 0.9429 - val_loss: 0.1569 - val_accuracy: 0.9561 - 1s/epoch - 121ms/step
# Epoch 112/250
# 12/12 - 2s - loss: 0.1823 - accuracy: 0.9297 - val_loss: 0.0805 - val_accuracy: 0.9649 - 2s/epoch - 126ms/step
# Epoch 113/250
# 12/12 - 1s - loss: 0.1398 - accuracy: 0.9560 - val_loss: 0.3314 - val_accuracy: 0.8772 - 1s/epoch - 120ms/step
# Epoch 114/250
# 12/12 - 2s - loss: 0.1742 - accuracy: 0.9451 - val_loss: 0.2287 - val_accuracy: 0.9123 - 2s/epoch - 131ms/step
# Epoch 115/250
# 12/12 - 1s - loss: 0.1471 - accuracy: 0.9495 - val_loss: 0.2534 - val_accuracy: 0.8947 - 1s/epoch - 123ms/step
# Epoch 116/250
# 12/12 - 2s - loss: 0.1667 - accuracy: 0.9407 - val_loss: 0.1237 - val_accuracy: 0.9474 - 2s/epoch - 127ms/step
# Epoch 117/250
# 12/12 - 2s - loss: 0.1454 - accuracy: 0.9538 - val_loss: 0.0879 - val_accuracy: 0.9649 - 2s/epoch - 130ms/step
# Epoch 118/250
# 12/12 - 2s - loss: 0.1571 - accuracy: 0.9363 - val_loss: 0.0822 - val_accuracy: 0.9561 - 2s/epoch - 133ms/step
# Epoch 119/250
# 12/12 - 1s - loss: 0.1194 - accuracy: 0.9560 - val_loss: 0.1209 - val_accuracy: 0.9649 - 1s/epoch - 119ms/step
# Epoch 120/250
# 12/12 - 1s - loss: 0.1643 - accuracy: 0.9495 - val_loss: 0.2547 - val_accuracy: 0.8596 - 1s/epoch - 125ms/step
# Epoch 121/250
# 12/12 - 2s - loss: 0.1505 - accuracy: 0.9560 - val_loss: 0.0940 - val_accuracy: 0.9737 - 2s/epoch - 131ms/step
# Epoch 122/250
# 12/12 - 1s - loss: 0.1408 - accuracy: 0.9626 - val_loss: 0.0698 - val_accuracy: 0.9649 - 1s/epoch - 122ms/step
# Epoch 123/250
# 12/12 - 1s - loss: 0.1482 - accuracy: 0.9516 - val_loss: 0.1287 - val_accuracy: 0.9737 - 1s/epoch - 121ms/step
# Epoch 124/250
# 12/12 - 1s - loss: 0.1498 - accuracy: 0.9451 - val_loss: 0.1223 - val_accuracy: 0.9737 - 1s/epoch - 121ms/step
# Epoch 125/250
# 12/12 - 1s - loss: 0.1476 - accuracy: 0.9516 - val_loss: 0.0826 - val_accuracy: 0.9737 - 1s/epoch - 123ms/step
# Epoch 126/250
# 12/12 - 2s - loss: 0.1750 - accuracy: 0.9363 - val_loss: 0.0708 - val_accuracy: 0.9825 - 2s/epoch - 131ms/step
# Epoch 127/250
# 12/12 - 1s - loss: 0.1539 - accuracy: 0.9429 - val_loss: 0.2446 - val_accuracy: 0.9211 - 1s/epoch - 120ms/step
# Epoch 128/250
# 12/12 - 2s - loss: 0.1447 - accuracy: 0.9516 - val_loss: 0.0824 - val_accuracy: 0.9649 - 2s/epoch - 129ms/step
# Epoch 129/250
# 12/12 - 2s - loss: 0.1808 - accuracy: 0.9451 - val_loss: 0.0907 - val_accuracy: 0.9649 - 2s/epoch - 135ms/step
# Epoch 130/250
# 12/12 - 1s - loss: 0.1641 - accuracy: 0.9429 - val_loss: 0.1698 - val_accuracy: 0.9298 - 1s/epoch - 122ms/step
# Epoch 131/250
# 12/12 - 1s - loss: 0.1717 - accuracy: 0.9429 - val_loss: 0.1099 - val_accuracy: 0.9649 - 1s/epoch - 120ms/step
# Epoch 132/250
# 12/12 - 2s - loss: 0.1540 - accuracy: 0.9473 - val_loss: 0.0576 - val_accuracy: 0.9825 - 2s/epoch - 133ms/step
# Epoch 133/250
# 12/12 - 2s - loss: 0.1440 - accuracy: 0.9516 - val_loss: 0.1909 - val_accuracy: 0.9298 - 2s/epoch - 132ms/step
# Epoch 134/250
# 12/12 - 1s - loss: 0.1468 - accuracy: 0.9385 - val_loss: 0.1940 - val_accuracy: 0.9474 - 1s/epoch - 119ms/step
# Epoch 135/250
# 12/12 - 2s - loss: 0.1358 - accuracy: 0.9604 - val_loss: 0.1873 - val_accuracy: 0.9035 - 2s/epoch - 129ms/step
# Epoch 136/250
# 12/12 - 2s - loss: 0.2012 - accuracy: 0.9231 - val_loss: 0.1148 - val_accuracy: 0.9737 - 2s/epoch - 127ms/step
# Epoch 137/250
# 12/12 - 2s - loss: 0.1454 - accuracy: 0.9495 - val_loss: 0.1818 - val_accuracy: 0.9211 - 2s/epoch - 126ms/step
# Epoch 138/250
# 12/12 - 1s - loss: 0.1851 - accuracy: 0.9319 - val_loss: 0.1490 - val_accuracy: 0.9649 - 1s/epoch - 124ms/step
# Epoch 139/250
# 12/12 - 2s - loss: 0.1483 - accuracy: 0.9451 - val_loss: 0.1182 - val_accuracy: 0.9649 - 2s/epoch - 130ms/step
# Epoch 140/250
# 12/12 - 1s - loss: 0.1636 - accuracy: 0.9407 - val_loss: 0.0834 - val_accuracy: 0.9737 - 1s/epoch - 124ms/step
# Epoch 141/250
# 12/12 - 1s - loss: 0.1231 - accuracy: 0.9626 - val_loss: 0.0578 - val_accuracy: 0.9737 - 1s/epoch - 119ms/step
# Epoch 142/250
# 12/12 - 1s - loss: 0.2377 - accuracy: 0.9121 - val_loss: 0.1813 - val_accuracy: 0.9474 - 1s/epoch - 120ms/step
# Epoch 143/250
# 12/12 - 1s - loss: 0.1421 - accuracy: 0.9604 - val_loss: 0.0951 - val_accuracy: 0.9737 - 1s/epoch - 123ms/step
# Epoch 144/250
# 12/12 - 1s - loss: 0.1340 - accuracy: 0.9604 - val_loss: 0.0739 - val_accuracy: 0.9737 - 1s/epoch - 120ms/step
# Epoch 145/250
# 12/12 - 1s - loss: 0.1597 - accuracy: 0.9385 - val_loss: 0.1079 - val_accuracy: 0.9649 - 1s/epoch - 121ms/step
# Epoch 146/250
# 12/12 - 2s - loss: 0.1594 - accuracy: 0.9495 - val_loss: 0.1083 - val_accuracy: 0.9561 - 2s/epoch - 129ms/step
# Epoch 147/250
# 12/12 - 2s - loss: 0.1705 - accuracy: 0.9385 - val_loss: 0.1282 - val_accuracy: 0.9561 - 2s/epoch - 129ms/step
# Epoch 148/250
# 12/12 - 1s - loss: 0.1370 - accuracy: 0.9538 - val_loss: 0.1357 - val_accuracy: 0.9474 - 1s/epoch - 125ms/step
# Epoch 149/250
# 12/12 - 1s - loss: 0.1600 - accuracy: 0.9473 - val_loss: 0.1300 - val_accuracy: 0.9298 - 1s/epoch - 124ms/step
# Epoch 150/250
# 12/12 - 1s - loss: 0.1493 - accuracy: 0.9538 - val_loss: 0.1092 - val_accuracy: 0.9737 - 1s/epoch - 118ms/step
# Epoch 151/250
# 12/12 - 1s - loss: 0.1734 - accuracy: 0.9407 - val_loss: 0.0726 - val_accuracy: 0.9912 - 1s/epoch - 124ms/step
# Epoch 152/250
# 12/12 - 1s - loss: 0.1803 - accuracy: 0.9451 - val_loss: 0.1387 - val_accuracy: 0.9474 - 1s/epoch - 119ms/step
# Epoch 153/250
# 12/12 - 1s - loss: 0.1511 - accuracy: 0.9451 - val_loss: 0.0730 - val_accuracy: 0.9737 - 1s/epoch - 124ms/step
# Epoch 154/250
# 12/12 - 2s - loss: 0.1597 - accuracy: 0.9516 - val_loss: 0.3984 - val_accuracy: 0.8421 - 2s/epoch - 128ms/step
# Epoch 155/250
# 12/12 - 2s - loss: 0.1779 - accuracy: 0.9429 - val_loss: 0.1111 - val_accuracy: 0.9649 - 2s/epoch - 128ms/step
# Epoch 156/250
# 12/12 - 1s - loss: 0.1425 - accuracy: 0.9451 - val_loss: 0.0697 - val_accuracy: 0.9825 - 1s/epoch - 119ms/step
# Epoch 157/250
# 12/12 - 1s - loss: 0.1486 - accuracy: 0.9451 - val_loss: 0.2062 - val_accuracy: 0.9386 - 1s/epoch - 125ms/step
# Epoch 158/250
# 12/12 - 2s - loss: 0.1442 - accuracy: 0.9582 - val_loss: 0.0799 - val_accuracy: 0.9649 - 2s/epoch - 128ms/step
# Epoch 159/250
# 12/12 - 1s - loss: 0.1331 - accuracy: 0.9473 - val_loss: 0.0773 - val_accuracy: 0.9561 - 1s/epoch - 119ms/step
# Epoch 160/250
# 12/12 - 2s - loss: 0.1656 - accuracy: 0.9363 - val_loss: 0.1143 - val_accuracy: 0.9561 - 2s/epoch - 128ms/step
# Epoch 161/250
# 12/12 - 2s - loss: 0.1384 - accuracy: 0.9538 - val_loss: 0.1362 - val_accuracy: 0.9474 - 2s/epoch - 132ms/step
# Epoch 162/250
# 12/12 - 2s - loss: 0.1494 - accuracy: 0.9495 - val_loss: 0.0492 - val_accuracy: 0.9825 - 2s/epoch - 126ms/step
# Epoch 163/250
# 12/12 - 1s - loss: 0.1662 - accuracy: 0.9429 - val_loss: 0.1084 - val_accuracy: 0.9561 - 1s/epoch - 120ms/step
# Epoch 164/250
# 12/12 - 1s - loss: 0.1206 - accuracy: 0.9626 - val_loss: 0.4884 - val_accuracy: 0.8421 - 1s/epoch - 120ms/step
# Epoch 165/250
# 12/12 - 2s - loss: 0.1659 - accuracy: 0.9385 - val_loss: 0.1335 - val_accuracy: 0.9649 - 2s/epoch - 130ms/step
# Epoch 166/250
# 12/12 - 2s - loss: 0.1477 - accuracy: 0.9516 - val_loss: 0.2107 - val_accuracy: 0.9386 - 2s/epoch - 130ms/step
# Epoch 167/250
# 12/12 - 2s - loss: 0.1496 - accuracy: 0.9495 - val_loss: 0.0805 - val_accuracy: 0.9737 - 2s/epoch - 126ms/step
# Epoch 168/250
# 12/12 - 2s - loss: 0.1370 - accuracy: 0.9560 - val_loss: 0.3072 - val_accuracy: 0.8684 - 2s/epoch - 127ms/step
# Epoch 169/250
# 12/12 - 1s - loss: 0.1626 - accuracy: 0.9385 - val_loss: 0.1225 - val_accuracy: 0.9474 - 1s/epoch - 123ms/step
# Epoch 170/250
# 12/12 - 2s - loss: 0.1294 - accuracy: 0.9604 - val_loss: 0.1944 - val_accuracy: 0.9298 - 2s/epoch - 132ms/step
# Epoch 171/250
# 12/12 - 1s - loss: 0.1686 - accuracy: 0.9407 - val_loss: 0.0716 - val_accuracy: 0.9912 - 1s/epoch - 121ms/step
# Epoch 172/250
# 12/12 - 1s - loss: 0.1433 - accuracy: 0.9560 - val_loss: 0.0609 - val_accuracy: 0.9737 - 1s/epoch - 121ms/step
# Epoch 173/250
# 12/12 - 2s - loss: 0.1436 - accuracy: 0.9473 - val_loss: 0.1107 - val_accuracy: 0.9561 - 2s/epoch - 127ms/step
# Epoch 174/250
# 12/12 - 2s - loss: 0.1466 - accuracy: 0.9429 - val_loss: 0.0998 - val_accuracy: 0.9649 - 2s/epoch - 125ms/step
# Epoch 175/250
# 12/12 - 2s - loss: 0.1393 - accuracy: 0.9604 - val_loss: 0.1243 - val_accuracy: 0.9474 - 2s/epoch - 126ms/step
# Epoch 176/250
# 12/12 - 1s - loss: 0.1510 - accuracy: 0.9516 - val_loss: 0.0902 - val_accuracy: 0.9737 - 1s/epoch - 124ms/step
# Epoch 177/250
# 12/12 - 2s - loss: 0.1500 - accuracy: 0.9429 - val_loss: 0.3025 - val_accuracy: 0.8684 - 2s/epoch - 127ms/step
# Epoch 178/250
# 12/12 - 2s - loss: 0.1841 - accuracy: 0.9297 - val_loss: 0.1268 - val_accuracy: 0.9649 - 2s/epoch - 131ms/step
# Epoch 179/250
# 12/12 - 1s - loss: 0.1533 - accuracy: 0.9451 - val_loss: 0.1092 - val_accuracy: 0.9649 - 1s/epoch - 118ms/step
# Epoch 180/250
# 12/12 - 2s - loss: 0.1082 - accuracy: 0.9648 - val_loss: 0.0577 - val_accuracy: 0.9825 - 2s/epoch - 125ms/step
# Epoch 181/250
# 12/12 - 2s - loss: 0.1380 - accuracy: 0.9516 - val_loss: 0.1689 - val_accuracy: 0.9386 - 2s/epoch - 127ms/step
# Epoch 182/250
# 12/12 - 2s - loss: 0.1568 - accuracy: 0.9495 - val_loss: 0.0911 - val_accuracy: 0.9825 - 2s/epoch - 126ms/step
# Epoch 183/250
# 12/12 - 1s - loss: 0.1202 - accuracy: 0.9582 - val_loss: 0.1414 - val_accuracy: 0.9561 - 1s/epoch - 124ms/step
# Epoch 184/250
# 12/12 - 2s - loss: 0.1534 - accuracy: 0.9538 - val_loss: 0.0825 - val_accuracy: 0.9649 - 2s/epoch - 127ms/step
# Epoch 185/250
# 12/12 - 1s - loss: 0.1530 - accuracy: 0.9429 - val_loss: 0.4585 - val_accuracy: 0.8421 - 1s/epoch - 123ms/step
# Epoch 186/250
# 12/12 - 2s - loss: 0.1690 - accuracy: 0.9473 - val_loss: 0.2122 - val_accuracy: 0.9298 - 2s/epoch - 128ms/step
# Epoch 187/250
# 12/12 - 2s - loss: 0.1316 - accuracy: 0.9538 - val_loss: 0.1070 - val_accuracy: 0.9649 - 2s/epoch - 128ms/step
# Epoch 188/250
# 12/12 - 1s - loss: 0.1190 - accuracy: 0.9582 - val_loss: 0.0809 - val_accuracy: 0.9737 - 1s/epoch - 121ms/step
# Epoch 189/250
# 12/12 - 2s - loss: 0.1399 - accuracy: 0.9473 - val_loss: 0.1216 - val_accuracy: 0.9474 - 2s/epoch - 128ms/step
# Epoch 190/250
# 12/12 - 2s - loss: 0.1346 - accuracy: 0.9582 - val_loss: 0.0762 - val_accuracy: 0.9561 - 2s/epoch - 131ms/step
# Epoch 191/250
# 12/12 - 1s - loss: 0.1432 - accuracy: 0.9451 - val_loss: 0.0780 - val_accuracy: 0.9737 - 1s/epoch - 124ms/step
# Epoch 192/250
# 12/12 - 2s - loss: 0.1478 - accuracy: 0.9473 - val_loss: 0.0866 - val_accuracy: 0.9649 - 2s/epoch - 125ms/step
# Epoch 193/250
# 12/12 - 2s - loss: 0.1862 - accuracy: 0.9341 - val_loss: 0.1014 - val_accuracy: 0.9737 - 2s/epoch - 129ms/step
# Epoch 194/250
# 12/12 - 1s - loss: 0.1230 - accuracy: 0.9626 - val_loss: 0.1730 - val_accuracy: 0.9298 - 1s/epoch - 123ms/step
# Epoch 195/250
# 12/12 - 1s - loss: 0.1315 - accuracy: 0.9495 - val_loss: 0.0705 - val_accuracy: 0.9737 - 1s/epoch - 125ms/step
# Epoch 196/250
# 12/12 - 1s - loss: 0.1374 - accuracy: 0.9495 - val_loss: 0.3220 - val_accuracy: 0.8158 - 1s/epoch - 122ms/step
# Epoch 197/250
# 12/12 - 1s - loss: 0.1318 - accuracy: 0.9538 - val_loss: 0.2257 - val_accuracy: 0.9298 - 1s/epoch - 120ms/step
# Epoch 198/250
# 12/12 - 2s - loss: 0.1429 - accuracy: 0.9495 - val_loss: 0.1216 - val_accuracy: 0.9649 - 2s/epoch - 126ms/step
# Epoch 199/250
# 12/12 - 2s - loss: 0.1184 - accuracy: 0.9626 - val_loss: 0.0698 - val_accuracy: 0.9649 - 2s/epoch - 131ms/step
# Epoch 200/250
# 12/12 - 1s - loss: 0.1089 - accuracy: 0.9670 - val_loss: 0.0712 - val_accuracy: 0.9825 - 1s/epoch - 125ms/step
# Epoch 201/250
# 12/12 - 2s - loss: 0.1463 - accuracy: 0.9495 - val_loss: 0.1209 - val_accuracy: 0.9561 - 2s/epoch - 133ms/step
# Epoch 202/250
# 12/12 - 1s - loss: 0.1461 - accuracy: 0.9385 - val_loss: 0.0837 - val_accuracy: 0.9825 - 1s/epoch - 122ms/step
# Epoch 203/250
# 12/12 - 2s - loss: 0.1435 - accuracy: 0.9582 - val_loss: 0.0690 - val_accuracy: 0.9737 - 2s/epoch - 133ms/step
# Epoch 204/250
# 12/12 - 2s - loss: 0.1524 - accuracy: 0.9516 - val_loss: 0.2881 - val_accuracy: 0.8947 - 2s/epoch - 131ms/step
# Epoch 205/250
# 12/12 - 1s - loss: 0.1819 - accuracy: 0.9341 - val_loss: 0.0837 - val_accuracy: 0.9649 - 1s/epoch - 118ms/step
# Epoch 206/250
# 12/12 - 1s - loss: 0.1172 - accuracy: 0.9670 - val_loss: 0.0638 - val_accuracy: 0.9649 - 1s/epoch - 124ms/step
# Epoch 207/250
# 12/12 - 2s - loss: 0.1678 - accuracy: 0.9363 - val_loss: 0.9445 - val_accuracy: 0.4825 - 2s/epoch - 133ms/step
# Epoch 208/250
# 12/12 - 2s - loss: 0.2175 - accuracy: 0.9231 - val_loss: 0.0743 - val_accuracy: 0.9737 - 2s/epoch - 126ms/step
# Epoch 209/250
# 12/12 - 2s - loss: 0.1379 - accuracy: 0.9429 - val_loss: 0.1812 - val_accuracy: 0.9298 - 2s/epoch - 126ms/step
# Epoch 210/250
# 12/12 - 1s - loss: 0.1405 - accuracy: 0.9473 - val_loss: 0.0895 - val_accuracy: 0.9737 - 1s/epoch - 124ms/step
# Epoch 211/250
# 12/12 - 1s - loss: 0.1346 - accuracy: 0.9604 - val_loss: 0.0927 - val_accuracy: 0.9649 - 1s/epoch - 124ms/step
# Epoch 212/250
# 12/12 - 2s - loss: 0.1220 - accuracy: 0.9626 - val_loss: 0.0972 - val_accuracy: 0.9561 - 2s/epoch - 129ms/step
# Epoch 213/250
# 12/12 - 2s - loss: 0.1719 - accuracy: 0.9385 - val_loss: 0.1420 - val_accuracy: 0.9825 - 2s/epoch - 127ms/step
# Epoch 214/250
# 12/12 - 1s - loss: 0.1398 - accuracy: 0.9516 - val_loss: 0.0935 - val_accuracy: 0.9561 - 1s/epoch - 123ms/step
# Epoch 215/250
# 12/12 - 2s - loss: 0.1265 - accuracy: 0.9560 - val_loss: 0.1823 - val_accuracy: 0.9386 - 2s/epoch - 127ms/step
# Epoch 216/250
# 12/12 - 1s - loss: 0.1359 - accuracy: 0.9495 - val_loss: 0.1257 - val_accuracy: 0.9561 - 1s/epoch - 123ms/step
# Epoch 217/250
# 12/12 - 2s - loss: 0.1210 - accuracy: 0.9582 - val_loss: 0.0870 - val_accuracy: 0.9649 - 2s/epoch - 130ms/step
# Epoch 218/250
# 12/12 - 1s - loss: 0.1211 - accuracy: 0.9538 - val_loss: 0.1361 - val_accuracy: 0.9474 - 1s/epoch - 123ms/step
# Epoch 219/250
# 12/12 - 2s - loss: 0.1529 - accuracy: 0.9451 - val_loss: 0.0829 - val_accuracy: 0.9649 - 2s/epoch - 128ms/step
# Epoch 220/250
# 12/12 - 1s - loss: 0.1331 - accuracy: 0.9604 - val_loss: 0.0741 - val_accuracy: 0.9737 - 1s/epoch - 124ms/step
# Epoch 221/250
# 12/12 - 1s - loss: 0.1135 - accuracy: 0.9626 - val_loss: 0.0555 - val_accuracy: 0.9737 - 1s/epoch - 122ms/step
# Epoch 222/250
# 12/12 - 1s - loss: 0.1288 - accuracy: 0.9582 - val_loss: 0.1604 - val_accuracy: 0.9298 - 1s/epoch - 122ms/step
# Epoch 223/250
# 12/12 - 1s - loss: 0.1398 - accuracy: 0.9538 - val_loss: 0.1332 - val_accuracy: 0.9561 - 1s/epoch - 119ms/step
# Epoch 224/250
# 12/12 - 2s - loss: 0.1265 - accuracy: 0.9582 - val_loss: 0.1402 - val_accuracy: 0.9386 - 2s/epoch - 126ms/step
# Epoch 225/250
# 12/12 - 1s - loss: 0.1658 - accuracy: 0.9363 - val_loss: 0.0447 - val_accuracy: 0.9912 - 1s/epoch - 121ms/step
# Epoch 226/250
# 12/12 - 2s - loss: 0.1446 - accuracy: 0.9473 - val_loss: 0.2703 - val_accuracy: 0.9211 - 2s/epoch - 131ms/step
# Epoch 227/250
# 12/12 - 1s - loss: 0.1435 - accuracy: 0.9516 - val_loss: 0.0960 - val_accuracy: 0.9737 - 1s/epoch - 118ms/step
# Epoch 228/250
# 12/12 - 1s - loss: 0.1411 - accuracy: 0.9560 - val_loss: 0.0903 - val_accuracy: 0.9649 - 1s/epoch - 123ms/step
# Epoch 229/250
# 12/12 - 1s - loss: 0.1205 - accuracy: 0.9407 - val_loss: 0.1405 - val_accuracy: 0.9474 - 1s/epoch - 124ms/step
# Epoch 230/250
# 12/12 - 1s - loss: 0.1364 - accuracy: 0.9429 - val_loss: 0.0801 - val_accuracy: 0.9649 - 1s/epoch - 124ms/step
# Epoch 231/250
# 12/12 - 1s - loss: 0.1346 - accuracy: 0.9582 - val_loss: 0.1445 - val_accuracy: 0.9386 - 1s/epoch - 121ms/step
# Epoch 232/250
# 12/12 - 1s - loss: 0.1147 - accuracy: 0.9648 - val_loss: 0.0789 - val_accuracy: 0.9649 - 1s/epoch - 120ms/step
# Epoch 233/250
# 12/12 - 2s - loss: 0.1697 - accuracy: 0.9407 - val_loss: 0.1045 - val_accuracy: 0.9649 - 2s/epoch - 135ms/step
# Epoch 234/250
# 12/12 - 1s - loss: 0.1673 - accuracy: 0.9429 - val_loss: 0.1232 - val_accuracy: 0.9561 - 1s/epoch - 123ms/step
# Epoch 235/250

# %%
# plot loss, acc graph
plot_history(hist_rnn)

# %%
loss, acc = model_RNN.evaluate(X_test, Y_test_oh)
print()
print("Test accuracy = ", acc)
# Out:
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1996 - accuracy: 0.9649
#
# Test accuracy =  0.9649122953414917

# %%
rnn_pred = model_RNN.predict(X_test)

# %%
# wanna save the model run this cell.
#model_RNN.save('Breast_cancer_RNN_model.h5')

# %%
# Get the confusion matrix values.
True_Positives,False_Positives,False_Negetives,True_Negetives = get_confusion_matrix(Y_test_oh,rnn_pred)

# %%
pre,rec,spe = get_cm_components(True_Positives,False_Positives,False_Negetives,True_Negetives)

# %%
# view model acc, precision, recall etc..
vals = {'Accuracy':acc,'Precision':pre,'Recall':rec,'Specificity':spe}
data = pd.DataFrame(vals, index= ["SimpleRNN"])
summary_table = pd.concat([summary_table,data])
summary_table
# Out:
#            Accuracy  Precision    Recall  Specificity
# LSTM       0.973684   0.958333  1.000000     0.933333
# SimpleRNN  0.964912   0.972222  0.972222     0.952381
# SimpleRNN  0.964912   0.958333  0.985714     0.931818

# %% [markdown]
# ## Load the model (for 2nd time use)

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('Breast_Cancer_LSTM.h5')

# %%
model.compile(optimizer= Adam(learning_rate= 0.001), loss= 'binary_crossentropy', metrics=['accuracy'])

# %%
Y_test_oh = convert_to_one_hot(Y_test.to_numpy(),2)  # converting Y_test to one_hot vec format

# %%
loss, acc = model.evaluate(X_test, Y_test_oh)
# Out:
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1762 - accuracy: 0.9123

# %%
pred = model.predict(X_test)

# %%
mse_lstm = mean_squared_error(Y_test_oh, pred)

# %% [markdown]
# ### Comparison between SVM and LSTM

# %%
# Lets see how their predictions on test dataset varies..
plt.figure(figsize=(14,8))
plt.plot(model_pred, data = X_test,color = 'b')
plt.plot(pred, data = X_test, color = 'r')
plt.title('SVM VS LSTM')
plt.tight_layout()

# %% [markdown]
# ##  That's it.
